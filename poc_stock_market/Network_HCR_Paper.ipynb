# %% [markdown]
# <h1>Neural network Modeling</h1>

# %%
import torch
import numpy as np
import pandas as pd
import torch.nn as nn
import seaborn as sns
import yfinance as yf
import torch.optim as optim
import torch.functional as F
#from torchviz import make_dot
from tqdm.notebook import tqdm
from datetime import timedelta
import matplotlib.pyplot as plt
#from torchsummary import summary
from IPython.display import Image
import plotly.graph_objects as go
from IPython.display import Image, display
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F
import warnings
import os
warnings.filterwarnings("ignore")
from pathlib import Path
from ray import tune
from ray import train
from ray.train import Checkpoint, get_checkpoint
from ray.tune.schedulers import ASHAScheduler
import ray.cloudpickle as pickle
import tempfile
from functools import partial
import sys

# %%
module_path = os.path.abspath(os.path.join('../hcr_nn/layers.py'))
if module_path not in sys.path:
    sys.path.append(module_path)

from hcr_nn.layers import *

# %% [markdown]
# <H2>Gathering data of CDPR stock tickers</H2>

# %%
#skip ticker generation if it's present in the folder. Yahoo sometimes is too heavily occupied and cannot answer
path = './data/prices/ticker.csv'

if not os.path.isfile(path):
    tck = yf.Ticker("ETH-USD")
    start_date = "2021-01-01"
    end_date = '2022-01-01'
    df = tck.history(start=start_date, end=end_date)
    df.to_csv('./data/CDPR_stock_data.csv', index=False)
else:
    df = pd.read_csv(path)

# %%
df.head(5)
# Out:
#                                   Open         High         Low        Close  \
# Date
# 2021-01-01 00:00:00+00:00   737.708374   749.201843  719.792236   730.367554
# 2021-01-02 00:00:00+00:00   730.402649   786.798462  718.109497   774.534973
# 2021-01-03 00:00:00+00:00   774.511841  1006.565002  771.561646   975.507690
# 2021-01-04 00:00:00+00:00   977.058838  1153.189209  912.305359  1040.233032
# 2021-01-05 00:00:00+00:00  1041.498779  1129.371460  986.811279  1100.006104
#
#                                 Volume  Dividends  Stock Splits
# Date
# 2021-01-01 00:00:00+00:00  13652004358        0.0           0.0
# 2021-01-02 00:00:00+00:00  19740771179        0.0           0.0
# 2021-01-03 00:00:00+00:00  45200463368        0.0           0.0
# 2021-01-04 00:00:00+00:00  56945985763        0.0           0.0
# 2021-01-05 00:00:00+00:00  41535932781        0.0           0.0

# %%
#use only if first block fails for some reason
#df.to_csv('./data/prices/ticker.csv', index=False)

# %% [markdown]
# <h2>Drop the dividends and Stock Splits columns. We don't include them in our analysis.</h2>

# %%
df = df.drop(['Dividends', 'Stock Splits'], axis=1)
df['Volume'] = df['Volume'].astype('float64')
columns=['Open', 'High', 'Low', 'Close', 'Volume']
df.columns == columns
# Out:
# array([ True,  True,  True,  True,  True])

# %% [markdown]
# <h2>Plot to check for missing data</h2>

# %%
plt.figure(figsize=(22,4))
sns.heatmap((df.isna().sum()).to_frame(name='').T,cmap='GnBu', annot=True,
             fmt='0.0f').set_title('Count of Missing Values', fontsize=18)
plt.show()

# %%
df.describe().T.style.background_gradient(cmap='GnBu', axis=1)
# Out:
# <style type="text/css">
# #T_453c9_row0_col0, #T_453c9_row1_col0, #T_453c9_row2_col0, #T_453c9_row3_col0, #T_453c9_row4_col0 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_453c9_row0_col1, #T_453c9_row3_col1 {
#   background-color: #6cc4c9;
#   color: #000000;
# }
# #T_453c9_row0_col2, #T_453c9_row1_col2 {
#   background-color: #dcf1d7;
#   color: #000000;
# }
# #T_453c9_row0_col3, #T_453c9_row1_col3, #T_453c9_row3_col3 {
#   background-color: #e8f6e2;
#   color: #000000;
# }
# #T_453c9_row0_col4 {
#   background-color: #b2e1b9;
#   color: #000000;
# }
# #T_453c9_row0_col5, #T_453c9_row3_col5 {
#   background-color: #77cac5;
#   color: #000000;
# }
# #T_453c9_row0_col6, #T_453c9_row3_col6 {
#   background-color: #2f90c0;
#   color: #f1f1f1;
# }
# #T_453c9_row0_col7, #T_453c9_row1_col7, #T_453c9_row2_col7, #T_453c9_row3_col7, #T_453c9_row4_col7 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_453c9_row1_col1 {
#   background-color: #68c1ca;
#   color: #000000;
# }
# #T_453c9_row1_col4 {
#   background-color: #aedfb8;
#   color: #000000;
# }
# #T_453c9_row1_col5, #T_453c9_row2_col1 {
#   background-color: #72c7c7;
#   color: #000000;
# }
# #T_453c9_row1_col6 {
#   background-color: #2788bc;
#   color: #f1f1f1;
# }
# #T_453c9_row2_col2, #T_453c9_row3_col2 {
#   background-color: #ddf2d7;
#   color: #000000;
# }
# #T_453c9_row2_col3 {
#   background-color: #e9f6e3;
#   color: #000000;
# }
# #T_453c9_row2_col4 {
#   background-color: #b4e2ba;
#   color: #000000;
# }
# #T_453c9_row2_col5 {
#   background-color: #80cec2;
#   color: #000000;
# }
# #T_453c9_row2_col6 {
#   background-color: #3192c1;
#   color: #f1f1f1;
# }
# #T_453c9_row3_col4 {
#   background-color: #b1e0b9;
#   color: #000000;
# }
# #T_453c9_row4_col1 {
#   background-color: #b7e3bc;
#   color: #000000;
# }
# #T_453c9_row4_col2 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_453c9_row4_col3 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_453c9_row4_col4 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_453c9_row4_col5 {
#   background-color: #c3e7c1;
#   color: #000000;
# }
# #T_453c9_row4_col6 {
#   background-color: #a6dcb6;
#   color: #000000;
# }
# </style>
# <table id="T_453c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_453c9_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_453c9_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_453c9_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_453c9_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_453c9_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_453c9_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_453c9_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_453c9_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_453c9_level0_row0" class="row_heading level0 row0" >Open</th>
#       <td id="T_453c9_row0_col0" class="data row0 col0" >365.000000</td>
#       <td id="T_453c9_row0_col1" class="data row0 col1" >2771.215477</td>
#       <td id="T_453c9_row0_col2" class="data row0 col2" >1029.448767</td>
#       <td id="T_453c9_row0_col3" class="data row0 col3" >730.402649</td>
#       <td id="T_453c9_row0_col4" class="data row0 col4" >1886.667603</td>
#       <td id="T_453c9_row0_col5" class="data row0 col5" >2629.748779</td>
#       <td id="T_453c9_row0_col6" class="data row0 col6" >3632.219727</td>
#       <td id="T_453c9_row0_col7" class="data row0 col7" >4810.071289</td>
#     </tr>
#     <tr>
#       <th id="T_453c9_level0_row1" class="row_heading level0 row1" >High</th>
#       <td id="T_453c9_row1_col0" class="data row1 col0" >365.000000</td>
#       <td id="T_453c9_row1_col1" class="data row1 col1" >2872.125942</td>
#       <td id="T_453c9_row1_col2" class="data row1 col2" >1048.947824</td>
#       <td id="T_453c9_row1_col3" class="data row1 col3" >749.201843</td>
#       <td id="T_453c9_row1_col4" class="data row1 col4" >1959.696289</td>
#       <td id="T_453c9_row1_col5" class="data row1 col5" >2750.534912</td>
#       <td id="T_453c9_row1_col6" class="data row1 col6" >3827.981934</td>
#       <td id="T_453c9_row1_col7" class="data row1 col7" >4891.704590</td>
#     </tr>
#     <tr>
#       <th id="T_453c9_level0_row2" class="row_heading level0 row2" >Low</th>
#       <td id="T_453c9_row2_col0" class="data row2 col0" >365.000000</td>
#       <td id="T_453c9_row2_col1" class="data row2 col1" >2658.899019</td>
#       <td id="T_453c9_row2_col2" class="data row2 col2" >1004.316330</td>
#       <td id="T_453c9_row2_col3" class="data row2 col3" >718.109497</td>
#       <td id="T_453c9_row2_col4" class="data row2 col4" >1811.245850</td>
#       <td id="T_453c9_row2_col5" class="data row2 col5" >2485.375000</td>
#       <td id="T_453c9_row2_col6" class="data row2 col6" >3544.640381</td>
#       <td id="T_453c9_row2_col7" class="data row2 col7" >4718.039062</td>
#     </tr>
#     <tr>
#       <th id="T_453c9_level0_row3" class="row_heading level0 row3" >Close</th>
#       <td id="T_453c9_row3_col0" class="data row3 col0" >365.000000</td>
#       <td id="T_453c9_row3_col1" class="data row3 col1" >2778.354149</td>
#       <td id="T_453c9_row3_col2" class="data row3 col2" >1023.543690</td>
#       <td id="T_453c9_row3_col3" class="data row3 col3" >730.367554</td>
#       <td id="T_453c9_row3_col4" class="data row3 col4" >1895.552124</td>
#       <td id="T_453c9_row3_col5" class="data row3 col5" >2633.518311</td>
#       <td id="T_453c9_row3_col6" class="data row3 col6" >3638.122070</td>
#       <td id="T_453c9_row3_col7" class="data row3 col7" >4812.087402</td>
#     </tr>
#     <tr>
#       <th id="T_453c9_level0_row4" class="row_heading level0 row4" >Volume</th>
#       <td id="T_453c9_row4_col0" class="data row4 col0" >365.000000</td>
#       <td id="T_453c9_row4_col1" class="data row4 col1" >27280819104.775341</td>
#       <td id="T_453c9_row4_col2" class="data row4 col2" >11663121397.180578</td>
#       <td id="T_453c9_row4_col3" class="data row4 col3" >10894785525.000000</td>
#       <td id="T_453c9_row4_col4" class="data row4 col4" >18991302378.000000</td>
#       <td id="T_453c9_row4_col5" class="data row4 col5" >23868866254.000000</td>
#       <td id="T_453c9_row4_col6" class="data row4 col6" >32275969215.000000</td>
#       <td id="T_453c9_row4_col7" class="data row4 col7" >84482912776.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <h2>Visualizing data.</h2>

# %%
plt.figure(figsize=(20, 12))
sns.heatmap(df.corr(numeric_only=True), cmap="GnBu", annot=True, linewidths=.6 , cbar = False)
plt.xticks(rotation=60, size=10)
plt.yticks(size=10)
plt.title('Analysis of Correlations', size=20)
plt.tight_layout()
plt.show()

# %%
corr = df.corr(numeric_only=True)
f, ax = plt.subplots(figsize=(15, 5))
mask = np.triu(np.ones_like(corr, dtype=bool))
cut_off = 0.25
extreme_1 = 0.5
extreme_2 = 0.75
extreme_3 = 0.9
mask |= np.abs(corr) < cut_off
corr = corr[~mask]
remove_empty_rows_and_cols = True
if remove_empty_rows_and_cols:
    wanted_cols = np.flatnonzero(np.count_nonzero(~mask, axis=1))
    wanted_rows = np.flatnonzero(np.count_nonzero(~mask, axis=0))
    corr = corr.iloc[wanted_cols, wanted_rows]

annot = [[f"{val:.4f}"
          + ('' if abs(val) < extreme_1 else '\n*')
          + ('' if abs(val) < extreme_2 else '*')
          + ('' if abs(val) < extreme_3 else '*')
          for val in row] for row in corr.to_numpy()]
heatmap = sns.heatmap(corr, vmin=-1, vmax=1, annot=annot, fmt='', cmap='GnBu')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize': 12}, pad=16)
plt.show()

# %% [markdown]
# <h2>Further analysis confirms strong correlation between prices. However the correlation between them and volume remains weak. It also further confirms multimodal distribution.<h2>

# %%
custom_palette = sns.color_palette(['#2a9d8f', '#f4a261'])
sns.pairplot(data=df, diag_kind='kde', palette=custom_palette,corner=True)
plt.gcf().set_facecolor('#ffffff')
plt.show()

# %%
palette = "GnBu"
for column in columns:
    plt.figure(figsize=(15, 2)) 
    sns.violinplot(x=df[column], palette=palette, inner="quartile")  
    plt.title(f'Distribution of {column}', fontsize=14)
    plt.xlabel(column, fontsize=14)
    plt.ylabel('Density', fontsize=14)
    plt.grid(True)
    plt.show()

# %%
palette = "GnBu" 
for column in columns:
    plt.figure(figsize=(15, 2)) 
    sns.boxplot(x=df[column], palette=palette)
    plt.title(f'Distribution of {column}', fontsize=14)
    plt.xlabel(column, fontsize=14)
    stats = df[column].describe()
    stats_text = "\n".join([f"{key}: {value:.2f}" for key, value in stats.items()])
    plt.text(0.95, 0.95, stats_text, transform=plt.gca().transAxes, 
             fontsize=12, verticalalignment='top', 
             horizontalalignment='center', bbox=dict(boxstyle='round,pad=0.2', edgecolor='black', facecolor='#f4a261'))
    plt.grid(True) 
    plt.show()

# %%
import matplotlib.pyplot as plt
x=df.index
colors = ['#264653', '#2a9d8f', '#f4a261', '#e76f51','#e9c46a', '#e9d8a6']
plt.figure(figsize=(28, 10))
plt.subplot(3, 2, 1)
plt.plot(x, df['Open'], color=colors[0], linewidth=2)
plt.title('Open', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3, 2, 2)
plt.plot(x, df['High'], color=colors[1], linewidth=2)
plt.title('High', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3, 2, 3)
plt.plot(x, df['Low'], color=colors[2], linewidth=2)
plt.title('Low', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3, 2, 4)
plt.plot(x, df['Close'], color=colors[3], linewidth=2)
plt.title('Close', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3, 2, 5)
plt.plot(x, df['Volume'], color=colors[4], linewidth=2)
plt.title('Volume', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.5)
plt.subplot(3, 2, 6)
plt.grid(True, linestyle='--', alpha=0.5)
plt.suptitle('Ethereum Stock Attributes from 2016 to 2024', fontsize=22, y=0.97)
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#                                   Open         High         Low        Close  \
# Date
# 2021-01-01 00:00:00+00:00   737.708374   749.201843  719.792236   730.367554
# 2021-01-02 00:00:00+00:00   730.402649   786.798462  718.109497   774.534973
# 2021-01-03 00:00:00+00:00   774.511841  1006.565002  771.561646   975.507690
# 2021-01-04 00:00:00+00:00   977.058838  1153.189209  912.305359  1040.233032
# 2021-01-05 00:00:00+00:00  1041.498779  1129.371460  986.811279  1100.006104
#
#                                  Volume
# Date
# 2021-01-01 00:00:00+00:00  1.365200e+10
# 2021-01-02 00:00:00+00:00  1.974077e+10
# 2021-01-03 00:00:00+00:00  4.520046e+10
# 2021-01-04 00:00:00+00:00  5.694599e+10
# 2021-01-05 00:00:00+00:00  4.153593e+10

# %%
df['Daily_Return'] = df['Close'].pct_change()
df['Daily_Return'].plot(legend=True, figsize=(15, 5), color='#2a9d8f', linewidth=2)
plt.title('Daily Return Percentage of Ethereum Stock', fontsize=15)
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# <h2>Modeling data</h2>

# %%
if os.path.isfile('./data/prices/masked_ticker.csv'):
    df5 = pd.read_csv('./data/prices/masked_ticker.csv')
else:
    tck = yf.Ticker("ETH-USD")
    # defining the start date 
    start_date = "2021-01-01"
    end_date = '2022-01-01'
    # historical data
    df5 = tck.history(start=start_date, end=end_date)
    df5 = df5.drop(['Dividends', 'Stock Splits'], axis=1)

# %%
df5.head(5)
# Out:
#                                   Open         High         Low        Close  \
# Date
# 2021-01-01 00:00:00+00:00   737.708374   749.201843  719.792236   730.367554
# 2021-01-02 00:00:00+00:00   730.402649   786.798462  718.109497   774.534973
# 2021-01-03 00:00:00+00:00   774.511841  1006.565002  771.561646   975.507690
# 2021-01-04 00:00:00+00:00   977.058838  1153.189209  912.305359  1040.233032
# 2021-01-05 00:00:00+00:00  1041.498779  1129.371460  986.811279  1100.006104
#
#                                 Volume
# Date
# 2021-01-01 00:00:00+00:00  13652004358
# 2021-01-02 00:00:00+00:00  19740771179
# 2021-01-03 00:00:00+00:00  45200463368
# 2021-01-04 00:00:00+00:00  56945985763
# 2021-01-05 00:00:00+00:00  41535932781

# %%
if os.path.isfile('../data/masked_ticker.csv'):
    pass
else:
    df5.to_csv('./data/masked_ticker.csv')

# %%
df5 = df5.reset_index()

# %%
df5['Volume'] = df5['Volume'].astype('float64')

# %% [markdown]
# <h2>Using indicators to further analyse the data</h2>

# %%
def get_tech_ind(data):
    data['MA5'] = data.iloc[:,4].rolling(window=7).mean() #Close column
    data['MA10'] = data.iloc[:,4].rolling(window=10).mean() #Close Column

    data['MACD'] = data.iloc[:,4].ewm(span=26).mean() - data.iloc[:,1].ewm(span=12,adjust=False).mean()
    #This is the difference of Closing price and Opening Price

    # Create Bands
    data['8SD'] = data.iloc[:, 4].rolling(8).std()
    data['upper_band'] = data['MA10'] + (data['8SD'] * 2)
    data['lower_band'] = data['MA10'] - (data['8SD'] * 2)

    # Create Exponential moving average
    data['EMA'] = data.iloc[:,4].ewm(com=0.5).mean()

    return data

# %%
start_date = '2015-01-01'
end_date = '2025-01-01'

mask = (df5['Date'] >= start_date) & (df5['Date'] < end_date)

df5 = df5.loc[mask]

# %%
df5.tail(3)
# Out:
#                          Date         Open         High          Low  \
# 362 2021-12-29 00:00:00+00:00  3797.436279  3827.981934  3612.795898
# 363 2021-12-30 00:00:00+00:00  3632.219727  3767.559814  3595.204834
# 364 2021-12-31 00:00:00+00:00  3713.430176  3807.288818  3636.869873
#
#            Close        Volume
# 362  3628.531738  1.572256e+10
# 363  3713.852051  1.292538e+10
# 364  3682.632812  1.415729e+10

# %% [markdown]
# <h2>Appending the data from sentiment analysis file we export into the other folder.</h2>

# %%
from matplotlib.dates import DateFormatter

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(df5['Date'], df5['Close'], color='#008B8B')
ax.set(xlabel="Date", ylabel="ETH", title="Ethereum Price for the masked 2021")

ax.xaxis.set_major_formatter(DateFormatter("%Y"))

plt.show()

# %%
tech_df = get_tech_ind(df5)
dataset = tech_df.iloc[10:,:].reset_index(drop=True)
dataset.head()
# Out:
#                        Date         Open         High          Low  \
# 0 2021-01-11 00:00:00+00:00  1261.622925  1261.622925   924.922607
# 1 2021-01-12 00:00:00+00:00  1088.526733  1149.240234  1012.764160
# 2 2021-01-13 00:00:00+00:00  1043.740967  1134.338501   994.549072
# 3 2021-01-14 00:00:00+00:00  1130.231201  1244.163086  1093.060791
# 4 2021-01-15 00:00:00+00:00  1221.877197  1250.505859  1090.721069
#
#          Close        Volume          MA5         MA10       MACD        8SD  \
# 0  1090.145386  6.073363e+10  1198.637556  1118.073859  36.767167  89.245201
# 1  1043.434570  3.749460e+10  1190.555908  1144.963818  26.421413  88.539272
# 2  1130.739380  3.010979e+10  1179.645508  1160.486987  34.872771  85.214707
# 3  1218.453003  3.341092e+10  1178.613351  1178.308984  38.569672  85.764193
# 4  1171.834595  3.597204e+10  1171.132987  1185.491833  22.663302  84.168607
#
#     upper_band   lower_band          EMA
# 0  1296.564261   939.583456  1147.247263
# 1  1322.042362   967.885275  1078.038671
# 2  1330.916402   990.057572  1113.172499
# 3  1349.837370  1006.780598  1183.359516
# 4  1353.829048  1017.154619  1175.676235

# %%
df5['Date'] = pd.to_datetime(df5['Date'], utc=True)

# %% [markdown]
# <h2>Visualize the indicators</h2>

# %%
def tech_ind(dataset):
    fig,ax = plt.subplots(figsize=(15, 8), dpi = 200)
    x_ = range(3, dataset.shape[0])
    x_ = list(dataset.index)

    ax.plot(dataset['Date'], dataset['MA5'], label='Moving Average (5 days)', color='g', linestyle='--')
    ax.plot(dataset['Date'], dataset['Close'], label='Closing Price', color='#6A5ACD')
    ax.plot(dataset['Date'], dataset['MA10'], label='Moving Average (10 days)', color='r', linestyle='-.')
    ax.plot(dataset['Date'], dataset['8SD'], label='Moving Average (8 days)', color='r', linestyle='-.')
    ax.plot(dataset['Date'], dataset['EMA'], label='Exponential Moving Average (8 days)', color='r', linestyle='-.')
    
    ax.xaxis.set_major_formatter(DateFormatter("%Y"))
    plt.title('Technical indicators')
    plt.ylabel('Close (USD)')
    plt.xlabel("Year")
    plt.legend()

    plt.show()

# %%
tech_ind(df5)

# %% [markdown]
# <h3>5 days and 10 days dataset copy</h3>

# %%
dataset_5_days = df5.iloc[6:,:].reset_index(drop=True)
dataset_5_days.head()
# Out:
#                        Date         Open         High          Low  \
# 0 2021-01-07 00:00:00+00:00  1208.078369  1282.579590  1167.443115
# 1 2021-01-08 00:00:00+00:00  1225.967896  1273.827515  1076.081543
# 2 2021-01-09 00:00:00+00:00  1223.740479  1303.871826  1182.270386
# 3 2021-01-10 00:00:00+00:00  1280.871094  1347.926147  1194.715576
# 4 2021-01-11 00:00:00+00:00  1261.622925  1261.622925   924.922607
#
#          Close        Volume          MA5         MA10        MACD  \
# 0  1225.678101  4.046803e+10  1007.634234          NaN  118.907470
# 1  1224.197144  4.433483e+10  1078.181318          NaN  101.722619
# 2  1281.077271  3.323311e+10  1150.544503          NaN   93.678942
# 3  1262.246704  4.061694e+10  1191.507220  1082.096075   73.782225
# 4  1090.145386  6.073363e+10  1198.637556  1118.073859   36.767167
#
#           8SD   upper_band  lower_band          EMA
# 0         NaN          NaN         NaN  1203.904779
# 1  196.472853          NaN         NaN  1217.435084
# 2  169.191093          NaN         NaN  1259.865364
# 3  111.858852  1305.813780  858.378371  1261.452951
# 4   89.245201  1296.564261  939.583456  1147.247263

# %%
dataset_10_days = df5.iloc[11:,:].reset_index(drop=True)
dataset_10_days.head()
# Out:
#                        Date         Open         High          Low  \
# 0 2021-01-12 00:00:00+00:00  1088.526733  1149.240234  1012.764160
# 1 2021-01-13 00:00:00+00:00  1043.740967  1134.338501   994.549072
# 2 2021-01-14 00:00:00+00:00  1130.231201  1244.163086  1093.060791
# 3 2021-01-15 00:00:00+00:00  1221.877197  1250.505859  1090.721069
# 4 2021-01-16 00:00:00+00:00  1171.443115  1290.053589  1157.623779
#
#          Close        Volume          MA5         MA10       MACD        8SD  \
# 0  1043.434570  3.749460e+10  1190.555908  1144.963818  26.421413  88.539272
# 1  1130.739380  3.010979e+10  1179.645508  1160.486987  34.872771  85.214707
# 2  1218.453003  3.341092e+10  1178.613351  1178.308984  38.569672  85.764193
# 3  1171.834595  3.597204e+10  1171.132987  1185.491833  22.663302  84.168607
# 4  1233.537598  3.231924e+10  1164.341605  1188.134375  23.505370  84.965703
#
#     upper_band   lower_band          EMA
# 0  1322.042362   967.885275  1078.038671
# 1  1330.916402   990.057572  1113.172499
# 2  1349.837370  1006.780598  1183.359516
# 3  1353.829048  1017.154619  1175.676235
# 4  1358.065782  1018.202968  1214.250478

# %%
dataset_5_days['Daily_Return'] = dataset_5_days['Close'].pct_change()

# plot the daily return percentage
dataset_5_days.Daily_Return.plot(legend=True, figsize=(15,5))
plt.title('Daily return percentage of Ethereum')
plt.show()

# %% [markdown]
# <h2>Final Data Preparation</h2>
# <h3>Change values for data training</h3>
#
# (ZACZYNAMY OD TEGO MIEJSCA)

# %%
dataset_5_days_trade_sign = dataset_5_days[['Open', 'Close', 'High', 'Low', 'trade_sign']]

# %%
# normalize 5 days data
scaler = MinMaxScaler(feature_range=(-1,1)).fit(dataset_5_days_trade_sign)

data_5_days_trade_sign = scaler.transform(dataset_5_days_trade_sign)
print(data_5_days_trade_sign)
# Out:
# [[-0.90248493 -0.89188569 -0.9107357  -0.85507255 -1.        ]
#  [-0.89186958 -0.89276426 -0.91600581 -0.90966917 -1.        ]
#  [-0.8931913  -0.85902064 -0.89791444 -0.84621194 -1.        ]
#  ...
#  [ 1.          0.9471445   0.98260568  0.98851831 -1.        ]
#  [ 0.94570572  0.92485278  0.96309646  0.94460869 -1.        ]
#  [ 0.92521806  0.94653735  0.95278307  0.93382262 -1.        ]]

# %% [markdown]
# <h2>5 day long sequences</h2>

# %%
seq_len_5_days=6
sequences_5_days_trade_sign=[]
for index in range(len(data_5_days_trade_sign) - seq_len_5_days + 1): 
    sequences_5_days_trade_sign.append(data_5_days_trade_sign[index: index + seq_len_5_days])
sequences_5_days_trade_sign = np.array(sequences_5_days_trade_sign)

sequences_5_days_trade_sign
# Out:
# array([[[-0.90248493, -0.89188569, -0.9107357 , -0.85507255,
#          -1.        ],
#         [-0.89186958, -0.89276426, -0.91600581, -0.90966917,
#          -1.        ],
#         [-0.8931913 , -0.85902064, -0.89791444, -0.84621194,
#          -1.        ],
#         [-0.85929094, -0.8701917 , -0.87138686, -0.83877484,
#          -1.        ],
#         [-0.87071249, -0.97228924, -0.92335488, -1.        ,
#          -1.        ],
#         [-0.97342487, -1.        , -0.99102683, -0.9475069 ,
#          -1.        ]],
#
#        [[-0.89186958, -0.89276426, -0.91600581, -0.90966917,
#          -1.        ],
#         [-0.8931913 , -0.85902064, -0.89791444, -0.84621194,
#          -1.        ],
#         [-0.85929094, -0.8701917 , -0.87138686, -0.83877484,
#          -1.        ],
#         [-0.87071249, -0.97228924, -0.92335488, -1.        ,
#          -1.        ],
#         [-0.97342487, -1.        , -0.99102683, -0.9475069 ,
#          -1.        ],
#         [-1.        , -0.94820722, -1.        , -0.95839203,
#          -1.        ]],
#
#        [[-0.8931913 , -0.85902064, -0.89791444, -0.84621194,
#          -1.        ],
#         [-0.85929094, -0.8701917 , -0.87138686, -0.83877484,
#          -1.        ],
#         [-0.87071249, -0.97228924, -0.92335488, -1.        ,
#          -1.        ],
#         [-0.97342487, -1.        , -0.99102683, -0.9475069 ,
#          -1.        ],
#         [-1.        , -0.94820722, -1.        , -0.95839203,
#          -1.        ],
#         [-0.94867814, -0.89617192, -0.93386844, -0.89952256,
#          -1.        ]],
#
#        ...,
#
#        [[ 0.80429158,  0.88320889,  0.86808661,  0.88067781,
#          -1.        ],
#         [ 0.88315941,  0.83173048,  0.89967835,  0.90146735,
#          -1.        ],
#         [ 0.83262419,  0.71258118,  0.90571285,  0.79595331,
#          -1.        ],
#         [ 0.70958147,  0.92440466,  0.90209874,  0.78128175,
#          -1.        ],
#         [ 0.9254965 ,  1.        ,  1.        ,  1.        ,
#          -1.        ],
#         [ 1.        ,  0.9471445 ,  0.98260568,  0.98851831,
#          -1.        ]],
#
#        [[ 0.88315941,  0.83173048,  0.89967835,  0.90146735,
#          -1.        ],
#         [ 0.83262419,  0.71258118,  0.90571285,  0.79595331,
#          -1.        ],
#         [ 0.70958147,  0.92440466,  0.90209874,  0.78128175,
#          -1.        ],
#         [ 0.9254965 ,  1.        ,  1.        ,  1.        ,
#          -1.        ],
#         [ 1.        ,  0.9471445 ,  0.98260568,  0.98851831,
#          -1.        ],
#         [ 0.94570572,  0.92485278,  0.96309646,  0.94460869,
#          -1.        ]],
#
#        [[ 0.83262419,  0.71258118,  0.90571285,  0.79595331,
#          -1.        ],
#         [ 0.70958147,  0.92440466,  0.90209874,  0.78128175,
#          -1.        ],
#         [ 0.9254965 ,  1.        ,  1.        ,  1.        ,
#          -1.        ],
#         [ 1.        ,  0.9471445 ,  0.98260568,  0.98851831,
#          -1.        ],
#         [ 0.94570572,  0.92485278,  0.96309646,  0.94460869,
#          -1.        ],
#         [ 0.92521806,  0.94653735,  0.95278307,  0.93382262,
#          -1.        ]]])

# %%
valid_set_size_percentage_trade_sign = 10 
test_set_size_percentage_trade_sign = 10 

valid_set_size_trade_sign = int(np.round(valid_set_size_percentage_trade_sign/100*sequences_5_days_trade_sign.shape[0]))  
test_set_size_trade_sign  = int(np.round(test_set_size_percentage_trade_sign/100*sequences_5_days_trade_sign.shape[0]))
train_set_size_trade_sign = sequences_5_days_trade_sign.shape[0] - (valid_set_size_trade_sign + test_set_size_trade_sign)

x_train_5_days_trade_sign = sequences_5_days_trade_sign[:train_set_size_trade_sign,:-1,:]
y_train_5_days_trade_sign = sequences_5_days_trade_sign[:train_set_size_trade_sign,-1,:]
    
x_valid_5_days_trade_sign = sequences_5_days_trade_sign[train_set_size_trade_sign:train_set_size_trade_sign+valid_set_size_trade_sign,:-1,:]
y_valid_5_days_trade_sign = sequences_5_days_trade_sign[train_set_size_trade_sign:train_set_size_trade_sign+valid_set_size_trade_sign,-1,:]
    
x_test_5_days_trade_sign = sequences_5_days_trade_sign[train_set_size_trade_sign+valid_set_size_trade_sign:,:-1,:]
y_test_5_days_trade_sign = sequences_5_days_trade_sign[train_set_size_trade_sign+valid_set_size_trade_sign:,-1,:]

# %% [markdown]
# <h2>Building Neural Network and its components with Torch<h2>

# %%
x_train_5_days_trade_sign = torch.tensor(x_train_5_days_trade_sign).float()
y_train_5_days_trade_sign = torch.tensor(y_train_5_days_trade_sign).float()

x_valid_5_days_trade_sign = torch.tensor(x_valid_5_days_trade_sign).float()
y_valid_5_days_trade_sign = torch.tensor(y_valid_5_days_trade_sign).float()

train_dataset_5_days_trade_sign = TensorDataset(x_train_5_days_trade_sign, y_train_5_days_trade_sign)
train_dataloader_5_days_trade_sign = DataLoader(train_dataset_5_days_trade_sign, batch_size=32, shuffle=False)

valid_dataset_5_days_trade_sign = TensorDataset(x_valid_5_days_trade_sign, y_valid_5_days_trade_sign)
valid_dataloader_5_days_trade_sign = DataLoader(valid_dataset_5_days_trade_sign, batch_size=32, shuffle=False)

# %%
from tqdm.notebook import tqdm
from torchsummary import summary

from torch import nn
class NeuralNetwork(nn.Module):
    #adjust number of features for every new data column
    def __init__(self, num_feature):
        super(NeuralNetwork, self).__init__()
        self.lstm    = nn.LSTM(num_feature,64,batch_first=True)
        self.dense   = nn.Linear(64,num_feature)
        self.dropout = nn.Dropout1d(p=0.3) # add to forward pass if needed to test
        
    def forward(self, x):
        output, (hidden, cell) = self.lstm(x)
        #x = F.relu(self.dense(hidden))
        x = self.dense(hidden)
        return x

model = NeuralNetwork(5)

# %% [markdown]
# <h2>Dynamic Network for parameter tuning</h2>
# <h3>Aborted</h3>

# %%
from tqdm.notebook import tqdm
from torchsummary import summary

from torch import nn
class TuningNeuralNetwork(nn.Module):
    #adjust number of features for every new data column
    def __init__(self, num_feature, Bias=True, Batch_First=True, Num_Layers=1, Dropout=0.0, LBias=True):
        super(NeuralNetwork, self).__init__()
        self.lstm    = nn.LSTM(num_feature, 64, batch_first=Batch_First, bias=Bias, num_layers=Num_Layers, dropout=Dropout)
        self.dense   = nn.Linear(64,num_feature, bias=LBias)
        self.dropout = nn.Dropout1d(p=0.3) # add to forward pass if needed to test
        
    def forward(self, x):
        output, (hidden, cell) = self.lstm(x)
        #x = F.relu(self.dense(hidden))
        x = self.dense(hidden)
        return x

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)
mse = nn.MSELoss()

# %%
summary(model, (5, ))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─LSTM: 1-1                              [-1, 64]                  18,176
# ├─Linear: 1-2                            [-1, 5]                   325
# ==========================================================================================
# Total params: 18,501
# Trainable params: 18,501
# Non-trainable params: 0
# Total mult-adds (M): 0.02
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.07
# Estimated Total Size (MB): 0.07
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─LSTM: 1-1                              [-1, 64]                  18,176
# ├─Linear: 1-2                            [-1, 5]                   325
# ==========================================================================================
# Total params: 18,501
# Trainable params: 18,501
# Non-trainable params: 0
# Total mult-adds (M): 0.02
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.07
# Estimated Total Size (MB): 0.07
# ==========================================================================================

# %%
def train(dataloader):
    epoch_loss = 0
    model.train()
    
    for batch in dataloader:
        optimizer.zero_grad()
        x,y= batch
        pred = model(x)
        loss = mse(pred[0],y)
        loss.backward()
        optimizer.step()      
        epoch_loss += loss.item()  
        
    return epoch_loss

# %%
def evaluate(dataloader):
    epoch_loss = 0
    model.eval()  
    
    with torch.no_grad():
      for batch in dataloader:   
          x,y= batch
          pred = model(x)
          loss = mse(pred[0],y)              
          epoch_loss += loss.item()  
        
    return epoch_loss / len(dataloader)

# %% [markdown]
# <h2>Training and Validation comparison plot function</h2>

# %%
def plot_loss(train_losses, valid_losses):
    plt.plot(train_losses, color='black', label='test loss')
    plt.plot(valid_losses, color='blue', label='validation loss')

    plt.title('Loss function comparison')
    plt.xlabel('time')
    plt.ylabel('loss values')
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# <h2>Network training loop</h2>
#
# <h3>This code chunk contains code for best fit model</h3>

# %%
#change for different number of iterations
n_epochs = 1300

train_losses = []
valid_losses = []

best_valid_loss = float('inf')

for epoch_instance in range(1, n_epochs + 1):

    train_loss = train(train_dataloader_5_days_trade_sign)
    valid_loss = evaluate(valid_dataloader_5_days_trade_sign)
    
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)

    #save the best model
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model, 'saved_weights.pt')
    
    #early stop step - comment out if you want to reach for worse results
    if valid_loss > train_loss:
        break

    print("Epoch ",epoch_instance+1)
    print(f'\tTrain Loss: {train_loss:.5f} | ' + f'\tVal Loss: {valid_loss:.5f}\n')
# Out:
# Epoch  2
# 	Train Loss: 2.51950 | 	Val Loss: 0.28154
#
# Epoch  3
# 	Train Loss: 2.05426 | 	Val Loss: 0.26463
#
# Epoch  4
# 	Train Loss: 1.63541 | 	Val Loss: 0.25105
#
# Epoch  5
# 	Train Loss: 1.28061 | 	Val Loss: 0.23899
#
# Epoch  6
# 	Train Loss: 1.09178 | 	Val Loss: 0.21046
#
# Epoch  7
# 	Train Loss: 0.92815 | 	Val Loss: 0.16553
#
# Epoch  8
# 	Train Loss: 0.74996 | 	Val Loss: 0.12263
#
# Epoch  9
# 	Train Loss: 0.60220 | 	Val Loss: 0.09227
#
# Epoch  10
# 	Train Loss: 0.51298 | 	Val Loss: 0.09040
#
# Epoch  11
# 	Train Loss: 0.51389 | 	Val Loss: 0.10133
#
# Epoch  12
# 	Train Loss: 0.50865 | 	Val Loss: 0.09671
#
# Epoch  13
# 	Train Loss: 0.49992 | 	Val Loss: 0.09199
#
# Epoch  14
# 	Train Loss: 0.49797 | 	Val Loss: 0.09116
#
# Epoch  15
# 	Train Loss: 0.49567 | 	Val Loss: 0.09188
#
# Epoch  16
# 	Train Loss: 0.49449 | 	Val Loss: 0.09268
#
# Epoch  17
# 	Train Loss: 0.49358 | 	Val Loss: 0.09262
#
# Epoch  18
# 	Train Loss: 0.49256 | 	Val Loss: 0.09222
#
# Epoch  19
# 	Train Loss: 0.49149 | 	Val Loss: 0.09205
#
# Epoch  20
# 	Train Loss: 0.49046 | 	Val Loss: 0.09206
#
# Epoch  21
# 	Train Loss: 0.48946 | 	Val Loss: 0.09204
#
# Epoch  22
# 	Train Loss: 0.48847 | 	Val Loss: 0.09194
#
# Epoch  23
# 	Train Loss: 0.48748 | 	Val Loss: 0.09182
#
# Epoch  24
# 	Train Loss: 0.48648 | 	Val Loss: 0.09171
#
# Epoch  25
# 	Train Loss: 0.48547 | 	Val Loss: 0.09161
#
# Epoch  26
# 	Train Loss: 0.48447 | 	Val Loss: 0.09151
#
# Epoch  27
# 	Train Loss: 0.48347 | 	Val Loss: 0.09142
#
# Epoch  28
# 	Train Loss: 0.48247 | 	Val Loss: 0.09132
#
# Epoch  29
# 	Train Loss: 0.48147 | 	Val Loss: 0.09121
#
# Epoch  30
# 	Train Loss: 0.48047 | 	Val Loss: 0.09111
#
# Epoch  31
# 	Train Loss: 0.47948 | 	Val Loss: 0.09101
#
# Epoch  32
# 	Train Loss: 0.47848 | 	Val Loss: 0.09090
#
# Epoch  33
# 	Train Loss: 0.47748 | 	Val Loss: 0.09080
#
# Epoch  34
# 	Train Loss: 0.47649 | 	Val Loss: 0.09069
#
# Epoch  35
# 	Train Loss: 0.47550 | 	Val Loss: 0.09059
#
# Epoch  36
# 	Train Loss: 0.47450 | 	Val Loss: 0.09048
#
# Epoch  37
# 	Train Loss: 0.47351 | 	Val Loss: 0.09037
#
# Epoch  38
# 	Train Loss: 0.47252 | 	Val Loss: 0.09026
#
# Epoch  39
# 	Train Loss: 0.47153 | 	Val Loss: 0.09014
#
# Epoch  40
# 	Train Loss: 0.47054 | 	Val Loss: 0.09003
#
# Epoch  41
# 	Train Loss: 0.46955 | 	Val Loss: 0.08991
#
# Epoch  42
# 	Train Loss: 0.46856 | 	Val Loss: 0.08979
#
# Epoch  43
# 	Train Loss: 0.46757 | 	Val Loss: 0.08967
#
# Epoch  44
# 	Train Loss: 0.46658 | 	Val Loss: 0.08955
#
# Epoch  45
# 	Train Loss: 0.46559 | 	Val Loss: 0.08943
#
# Epoch  46
# 	Train Loss: 0.46460 | 	Val Loss: 0.08930
#
# Epoch  47
# 	Train Loss: 0.46361 | 	Val Loss: 0.08917
#
# Epoch  48
# 	Train Loss: 0.46263 | 	Val Loss: 0.08904
#
# Epoch  49
# 	Train Loss: 0.46164 | 	Val Loss: 0.08891
#
# Epoch  50
# 	Train Loss: 0.46066 | 	Val Loss: 0.08878
#
# Epoch  51
# 	Train Loss: 0.45968 | 	Val Loss: 0.08864
#
# Epoch  52
# 	Train Loss: 0.45870 | 	Val Loss: 0.08851
#
# Epoch  53
# 	Train Loss: 0.45773 | 	Val Loss: 0.08837
#
# Epoch  54
# 	Train Loss: 0.45677 | 	Val Loss: 0.08823
#
# Epoch  55
# 	Train Loss: 0.45581 | 	Val Loss: 0.08810
#
# Epoch  56
# 	Train Loss: 0.45487 | 	Val Loss: 0.08796
#
# Epoch  57
# 	Train Loss: 0.45394 | 	Val Loss: 0.08783
#
# Epoch  58
# 	Train Loss: 0.45302 | 	Val Loss: 0.08769
#
# Epoch  59
# 	Train Loss: 0.45213 | 	Val Loss: 0.08756
#
# Epoch  60
# 	Train Loss: 0.45126 | 	Val Loss: 0.08744
#
# Epoch  61
# 	Train Loss: 0.45041 | 	Val Loss: 0.08732
#
# Epoch  62
# 	Train Loss: 0.44960 | 	Val Loss: 0.08721
#
# Epoch  63
# 	Train Loss: 0.44882 | 	Val Loss: 0.08710
#
# Epoch  64
# 	Train Loss: 0.44807 | 	Val Loss: 0.08700
#
# Epoch  65
# 	Train Loss: 0.44737 | 	Val Loss: 0.08691
#
# Epoch  66
# 	Train Loss: 0.44670 | 	Val Loss: 0.08682
#
# Epoch  67
# 	Train Loss: 0.44607 | 	Val Loss: 0.08675
#
# Epoch  68
# 	Train Loss: 0.44548 | 	Val Loss: 0.08668
#
# Epoch  69
# 	Train Loss: 0.44493 | 	Val Loss: 0.08662
#
# Epoch  70
# 	Train Loss: 0.44442 | 	Val Loss: 0.08656
#
# Epoch  71
# 	Train Loss: 0.44395 | 	Val Loss: 0.08651
#
# Epoch  72
# 	Train Loss: 0.44351 | 	Val Loss: 0.08647
#
# Epoch  73
# 	Train Loss: 0.44310 | 	Val Loss: 0.08643
#
# Epoch  74
# 	Train Loss: 0.44272 | 	Val Loss: 0.08639
#
# Epoch  75
# 	Train Loss: 0.44236 | 	Val Loss: 0.08636
#
# Epoch  76
# 	Train Loss: 0.44203 | 	Val Loss: 0.08633
#
# Epoch  77
# 	Train Loss: 0.44172 | 	Val Loss: 0.08630
#
# Epoch  78
# 	Train Loss: 0.44142 | 	Val Loss: 0.08628
#
# Epoch  79
# 	Train Loss: 0.44114 | 	Val Loss: 0.08625
#
# Epoch  80
# 	Train Loss: 0.44088 | 	Val Loss: 0.08623
#
# Epoch  81
# 	Train Loss: 0.44062 | 	Val Loss: 0.08621
#
# Epoch  82
# 	Train Loss: 0.44038 | 	Val Loss: 0.08619
#
# Epoch  83
# 	Train Loss: 0.44015 | 	Val Loss: 0.08616
#
# Epoch  84
# 	Train Loss: 0.43992 | 	Val Loss: 0.08615
#
# Epoch  85
# 	Train Loss: 0.43971 | 	Val Loss: 0.08613
#
# Epoch  86
# 	Train Loss: 0.43950 | 	Val Loss: 0.08611
#
# Epoch  87
# 	Train Loss: 0.43929 | 	Val Loss: 0.08609
#
# Epoch  88
# 	Train Loss: 0.43909 | 	Val Loss: 0.08607
#
# Epoch  89
# 	Train Loss: 0.43890 | 	Val Loss: 0.08605
#
# Epoch  90
# 	Train Loss: 0.43871 | 	Val Loss: 0.08603
#
# Epoch  91
# 	Train Loss: 0.43852 | 	Val Loss: 0.08602
#
# Epoch  92
# 	Train Loss: 0.43834 | 	Val Loss: 0.08600
#
# Epoch  93
# 	Train Loss: 0.43816 | 	Val Loss: 0.08598
#
# Epoch  94
# 	Train Loss: 0.43799 | 	Val Loss: 0.08596
#
# Epoch  95
# 	Train Loss: 0.43781 | 	Val Loss: 0.08595
#
# Epoch  96
# 	Train Loss: 0.43764 | 	Val Loss: 0.08593
#
# Epoch  97
# 	Train Loss: 0.43748 | 	Val Loss: 0.08591
#
# Epoch  98
# 	Train Loss: 0.43731 | 	Val Loss: 0.08590
#
# Epoch  99
# 	Train Loss: 0.43715 | 	Val Loss: 0.08588
#
# Epoch  100
# 	Train Loss: 0.43699 | 	Val Loss: 0.08586
#
# Epoch  101
# 	Train Loss: 0.43683 | 	Val Loss: 0.08585
#
# Epoch  102
# 	Train Loss: 0.43667 | 	Val Loss: 0.08583
#
# Epoch  103
# 	Train Loss: 0.43651 | 	Val Loss: 0.08582
#
# Epoch  104
# 	Train Loss: 0.43636 | 	Val Loss: 0.08580
#
# Epoch  105
# 	Train Loss: 0.43621 | 	Val Loss: 0.08578
#
# Epoch  106
# 	Train Loss: 0.43606 | 	Val Loss: 0.08577
#
# Epoch  107
# 	Train Loss: 0.43591 | 	Val Loss: 0.08575
#
# Epoch  108
# 	Train Loss: 0.43576 | 	Val Loss: 0.08574
#
# Epoch  109
# 	Train Loss: 0.43561 | 	Val Loss: 0.08572
#
# Epoch  110
# 	Train Loss: 0.43546 | 	Val Loss: 0.08570
#
# Epoch  111
# 	Train Loss: 0.43532 | 	Val Loss: 0.08569
#
# Epoch  112
# 	Train Loss: 0.43517 | 	Val Loss: 0.08567
#
# Epoch  113
# 	Train Loss: 0.43503 | 	Val Loss: 0.08566
#
# Epoch  114
# 	Train Loss: 0.43489 | 	Val Loss: 0.08564
#
# Epoch  115
# 	Train Loss: 0.43475 | 	Val Loss: 0.08562
#
# Epoch  116
# 	Train Loss: 0.43461 | 	Val Loss: 0.08561
#
# Epoch  117
# 	Train Loss: 0.43447 | 	Val Loss: 0.08559
#
# Epoch  118
# 	Train Loss: 0.43433 | 	Val Loss: 0.08557
#
# Epoch  119
# 	Train Loss: 0.43420 | 	Val Loss: 0.08556
#
# Epoch  120
# 	Train Loss: 0.43406 | 	Val Loss: 0.08554
#
# Epoch  121
# 	Train Loss: 0.43393 | 	Val Loss: 0.08553
#
# Epoch  122
# 	Train Loss: 0.43380 | 	Val Loss: 0.08551
#
# Epoch  123
# 	Train Loss: 0.43366 | 	Val Loss: 0.08549
#
# Epoch  124
# 	Train Loss: 0.43353 | 	Val Loss: 0.08548
#
# Epoch  125
# 	Train Loss: 0.43340 | 	Val Loss: 0.08546
#
# Epoch  126
# 	Train Loss: 0.43327 | 	Val Loss: 0.08545
#
# Epoch  127
# 	Train Loss: 0.43314 | 	Val Loss: 0.08543
#
# Epoch  128
# 	Train Loss: 0.43302 | 	Val Loss: 0.08541
#
# Epoch  129
# 	Train Loss: 0.43289 | 	Val Loss: 0.08540
#
# Epoch  130
# 	Train Loss: 0.43276 | 	Val Loss: 0.08538
#
# Epoch  131
# 	Train Loss: 0.43264 | 	Val Loss: 0.08537
#
# Epoch  132
# 	Train Loss: 0.43252 | 	Val Loss: 0.08535
#
# Epoch  133
# 	Train Loss: 0.43240 | 	Val Loss: 0.08533
#
# Epoch  134
# 	Train Loss: 0.43227 | 	Val Loss: 0.08532
#
# Epoch  135
# 	Train Loss: 0.43215 | 	Val Loss: 0.08530
#
# Epoch  136
# 	Train Loss: 0.43203 | 	Val Loss: 0.08529
#
# Epoch  137
# 	Train Loss: 0.43192 | 	Val Loss: 0.08527
#
# Epoch  138
# 	Train Loss: 0.43180 | 	Val Loss: 0.08526
#
# Epoch  139
# 	Train Loss: 0.43168 | 	Val Loss: 0.08524
#
# Epoch  140
# 	Train Loss: 0.43157 | 	Val Loss: 0.08523
#
# Epoch  141
# 	Train Loss: 0.43146 | 	Val Loss: 0.08521
#
# Epoch  142
# 	Train Loss: 0.43134 | 	Val Loss: 0.08520
#
# Epoch  143
# 	Train Loss: 0.43123 | 	Val Loss: 0.08518
#
# Epoch  144
# 	Train Loss: 0.43112 | 	Val Loss: 0.08517
#
# Epoch  145
# 	Train Loss: 0.43101 | 	Val Loss: 0.08516
#
# Epoch  146
# 	Train Loss: 0.43090 | 	Val Loss: 0.08514
#
# Epoch  147
# 	Train Loss: 0.43080 | 	Val Loss: 0.08513
#
# Epoch  148
# 	Train Loss: 0.43069 | 	Val Loss: 0.08512
#
# Epoch  149
# 	Train Loss: 0.43058 | 	Val Loss: 0.08510
#
# Epoch  150
# 	Train Loss: 0.43048 | 	Val Loss: 0.08509
#
# Epoch  151
# 	Train Loss: 0.43038 | 	Val Loss: 0.08508
#
# Epoch  152
# 	Train Loss: 0.43028 | 	Val Loss: 0.08506
#
# Epoch  153
# 	Train Loss: 0.43017 | 	Val Loss: 0.08505
#
# Epoch  154
# 	Train Loss: 0.43007 | 	Val Loss: 0.08504
#
# Epoch  155
# 	Train Loss: 0.42998 | 	Val Loss: 0.08503
#
# Epoch  156
# 	Train Loss: 0.42988 | 	Val Loss: 0.08502
#
# Epoch  157
# 	Train Loss: 0.42978 | 	Val Loss: 0.08501
#
# Epoch  158
# 	Train Loss: 0.42969 | 	Val Loss: 0.08499
#
# Epoch  159
# 	Train Loss: 0.42959 | 	Val Loss: 0.08498
#
# Epoch  160
# 	Train Loss: 0.42950 | 	Val Loss: 0.08497
#
# Epoch  161
# 	Train Loss: 0.42940 | 	Val Loss: 0.08496
#
# Epoch  162
# 	Train Loss: 0.42931 | 	Val Loss: 0.08495
#
# Epoch  163
# 	Train Loss: 0.42922 | 	Val Loss: 0.08494
#
# Epoch  164
# 	Train Loss: 0.42913 | 	Val Loss: 0.08493
#
# Epoch  165
# 	Train Loss: 0.42904 | 	Val Loss: 0.08492
#
# Epoch  166
# 	Train Loss: 0.42895 | 	Val Loss: 0.08491
#
# Epoch  167
# 	Train Loss: 0.42887 | 	Val Loss: 0.08490
#
# Epoch  168
# 	Train Loss: 0.42878 | 	Val Loss: 0.08490
#
# Epoch  169
# 	Train Loss: 0.42869 | 	Val Loss: 0.08489
#
# Epoch  170
# 	Train Loss: 0.42861 | 	Val Loss: 0.08488
#
# Epoch  171
# 	Train Loss: 0.42852 | 	Val Loss: 0.08487
#
# Epoch  172
# 	Train Loss: 0.42844 | 	Val Loss: 0.08486
#
# Epoch  173
# 	Train Loss: 0.42836 | 	Val Loss: 0.08486
#
# Epoch  174
# 	Train Loss: 0.42827 | 	Val Loss: 0.08485
#
# Epoch  175
# 	Train Loss: 0.42819 | 	Val Loss: 0.08484
#
# Epoch  176
# 	Train Loss: 0.42811 | 	Val Loss: 0.08483
#
# Epoch  177
# 	Train Loss: 0.42803 | 	Val Loss: 0.08483
#
# Epoch  178
# 	Train Loss: 0.42795 | 	Val Loss: 0.08482
#
# Epoch  179
# 	Train Loss: 0.42787 | 	Val Loss: 0.08481
#
# Epoch  180
# 	Train Loss: 0.42779 | 	Val Loss: 0.08481
#
# Epoch  181
# 	Train Loss: 0.42771 | 	Val Loss: 0.08480
#
# Epoch  182
# 	Train Loss: 0.42763 | 	Val Loss: 0.08480
#
# Epoch  183
# 	Train Loss: 0.42755 | 	Val Loss: 0.08479
#
# Epoch  184
# 	Train Loss: 0.42748 | 	Val Loss: 0.08479
#
# Epoch  185
# 	Train Loss: 0.42740 | 	Val Loss: 0.08478
#
# Epoch  186
# 	Train Loss: 0.42732 | 	Val Loss: 0.08478
#
# Epoch  187
# 	Train Loss: 0.42724 | 	Val Loss: 0.08477
#
# Epoch  188
# 	Train Loss: 0.42717 | 	Val Loss: 0.08477
#
# Epoch  189
# 	Train Loss: 0.42709 | 	Val Loss: 0.08476
#
# Epoch  190
# 	Train Loss: 0.42701 | 	Val Loss: 0.08476
#
# Epoch  191
# 	Train Loss: 0.42694 | 	Val Loss: 0.08475
#
# Epoch  192
# 	Train Loss: 0.42686 | 	Val Loss: 0.08475
#
# Epoch  193
# 	Train Loss: 0.42679 | 	Val Loss: 0.08474
#
# Epoch  194
# 	Train Loss: 0.42671 | 	Val Loss: 0.08474
#
# Epoch  195
# 	Train Loss: 0.42663 | 	Val Loss: 0.08474
#
# Epoch  196
# 	Train Loss: 0.42656 | 	Val Loss: 0.08473
#
# Epoch  197
# 	Train Loss: 0.42648 | 	Val Loss: 0.08473
#
# Epoch  198
# 	Train Loss: 0.42640 | 	Val Loss: 0.08473
#
# Epoch  199
# 	Train Loss: 0.42633 | 	Val Loss: 0.08472
#
# Epoch  200
# 	Train Loss: 0.42625 | 	Val Loss: 0.08472
#
# Epoch  201
# 	Train Loss: 0.42618 | 	Val Loss: 0.08472
#
# Epoch  202
# 	Train Loss: 0.42610 | 	Val Loss: 0.08471
#
# Epoch  203
# 	Train Loss: 0.42602 | 	Val Loss: 0.08471
#
# Epoch  204
# 	Train Loss: 0.42594 | 	Val Loss: 0.08471
#
# Epoch  205
# 	Train Loss: 0.42587 | 	Val Loss: 0.08470
#
# Epoch  206
# 	Train Loss: 0.42579 | 	Val Loss: 0.08470
#
# Epoch  207
# 	Train Loss: 0.42571 | 	Val Loss: 0.08470
#
# Epoch  208
# 	Train Loss: 0.42563 | 	Val Loss: 0.08469
#
# Epoch  209
# 	Train Loss: 0.42555 | 	Val Loss: 0.08469
#
# Epoch  210
# 	Train Loss: 0.42548 | 	Val Loss: 0.08469
#
# Epoch  211
# 	Train Loss: 0.42540 | 	Val Loss: 0.08469
#
# Epoch  212
# 	Train Loss: 0.42532 | 	Val Loss: 0.08468
#
# Epoch  213
# 	Train Loss: 0.42524 | 	Val Loss: 0.08468
#
# Epoch  214
# 	Train Loss: 0.42515 | 	Val Loss: 0.08468
#
# Epoch  215
# 	Train Loss: 0.42507 | 	Val Loss: 0.08468
#
# Epoch  216
# 	Train Loss: 0.42499 | 	Val Loss: 0.08467
#
# Epoch  217
# 	Train Loss: 0.42491 | 	Val Loss: 0.08467
#
# Epoch  218
# 	Train Loss: 0.42483 | 	Val Loss: 0.08467
#
# Epoch  219
# 	Train Loss: 0.42474 | 	Val Loss: 0.08467
#
# Epoch  220
# 	Train Loss: 0.42466 | 	Val Loss: 0.08466
#
# Epoch  221
# 	Train Loss: 0.42457 | 	Val Loss: 0.08466
#
# Epoch  222
# 	Train Loss: 0.42448 | 	Val Loss: 0.08466
#
# Epoch  223
# 	Train Loss: 0.42440 | 	Val Loss: 0.08466
#
# Epoch  224
# 	Train Loss: 0.42431 | 	Val Loss: 0.08465
#
# Epoch  225
# 	Train Loss: 0.42422 | 	Val Loss: 0.08465
#
# Epoch  226
# 	Train Loss: 0.42413 | 	Val Loss: 0.08465
#
# Epoch  227
# 	Train Loss: 0.42404 | 	Val Loss: 0.08465
#
# Epoch  228
# 	Train Loss: 0.42395 | 	Val Loss: 0.08464
#
# Epoch  229
# 	Train Loss: 0.42386 | 	Val Loss: 0.08464
#
# Epoch  230
# 	Train Loss: 0.42376 | 	Val Loss: 0.08464
#
# Epoch  231
# 	Train Loss: 0.42367 | 	Val Loss: 0.08464
#
# Epoch  232
# 	Train Loss: 0.42357 | 	Val Loss: 0.08463
#
# Epoch  233
# 	Train Loss: 0.42347 | 	Val Loss: 0.08463
#
# Epoch  234
# 	Train Loss: 0.42337 | 	Val Loss: 0.08463
#
# Epoch  235
# 	Train Loss: 0.42327 | 	Val Loss: 0.08463
#
# Epoch  236
# 	Train Loss: 0.42317 | 	Val Loss: 0.08462
#
# Epoch  237
# 	Train Loss: 0.42307 | 	Val Loss: 0.08462
#
# Epoch  238
# 	Train Loss: 0.42296 | 	Val Loss: 0.08462
#
# Epoch  239
# 	Train Loss: 0.42286 | 	Val Loss: 0.08462
#
# Epoch  240
# 	Train Loss: 0.42275 | 	Val Loss: 0.08461
#
# Epoch  241
# 	Train Loss: 0.42264 | 	Val Loss: 0.08461
#
# Epoch  242
# 	Train Loss: 0.42253 | 	Val Loss: 0.08461
#
# Epoch  243
# 	Train Loss: 0.42241 | 	Val Loss: 0.08460
#
# Epoch  244
# 	Train Loss: 0.42230 | 	Val Loss: 0.08460
#
# Epoch  245
# 	Train Loss: 0.42218 | 	Val Loss: 0.08460
#
# Epoch  246
# 	Train Loss: 0.42206 | 	Val Loss: 0.08459
#
# Epoch  247
# 	Train Loss: 0.42193 | 	Val Loss: 0.08459
#
# Epoch  248
# 	Train Loss: 0.42181 | 	Val Loss: 0.08458
#
# Epoch  249
# 	Train Loss: 0.42168 | 	Val Loss: 0.08458
#
# Epoch  250
# 	Train Loss: 0.42155 | 	Val Loss: 0.08457
#
# Epoch  251
# 	Train Loss: 0.42142 | 	Val Loss: 0.08457
#
# Epoch  252
# 	Train Loss: 0.42128 | 	Val Loss: 0.08457
#
# Epoch  253
# 	Train Loss: 0.42114 | 	Val Loss: 0.08456
#
# Epoch  254
# 	Train Loss: 0.42100 | 	Val Loss: 0.08456
#
# Epoch  255
# 	Train Loss: 0.42085 | 	Val Loss: 0.08455
#
# Epoch  256
# 	Train Loss: 0.42070 | 	Val Loss: 0.08455
#
# Epoch  257
# 	Train Loss: 0.42055 | 	Val Loss: 0.08454
#
# Epoch  258
# 	Train Loss: 0.42039 | 	Val Loss: 0.08454
#
# Epoch  259
# 	Train Loss: 0.42023 | 	Val Loss: 0.08453
#
# Epoch  260
# 	Train Loss: 0.42007 | 	Val Loss: 0.08452
#
# Epoch  261
# 	Train Loss: 0.41990 | 	Val Loss: 0.08452
#
# Epoch  262
# 	Train Loss: 0.41972 | 	Val Loss: 0.08451
#
# Epoch  263
# 	Train Loss: 0.41955 | 	Val Loss: 0.08451
#
# Epoch  264
# 	Train Loss: 0.41936 | 	Val Loss: 0.08450
#
# Epoch  265
# 	Train Loss: 0.41918 | 	Val Loss: 0.08450
#
# Epoch  266
# 	Train Loss: 0.41898 | 	Val Loss: 0.08449
#
# Epoch  267
# 	Train Loss: 0.41879 | 	Val Loss: 0.08448
#
# Epoch  268
# 	Train Loss: 0.41858 | 	Val Loss: 0.08448
#
# Epoch  269
# 	Train Loss: 0.41837 | 	Val Loss: 0.08447
#
# Epoch  270
# 	Train Loss: 0.41816 | 	Val Loss: 0.08447
#
# Epoch  271
# 	Train Loss: 0.41794 | 	Val Loss: 0.08446
#
# Epoch  272
# 	Train Loss: 0.41771 | 	Val Loss: 0.08446
#
# Epoch  273
# 	Train Loss: 0.41748 | 	Val Loss: 0.08445
#
# Epoch  274
# 	Train Loss: 0.41725 | 	Val Loss: 0.08445
#
# Epoch  275
# 	Train Loss: 0.41700 | 	Val Loss: 0.08444
#
# Epoch  276
# 	Train Loss: 0.41675 | 	Val Loss: 0.08444
#
# Epoch  277
# 	Train Loss: 0.41649 | 	Val Loss: 0.08443
#
# Epoch  278
# 	Train Loss: 0.41623 | 	Val Loss: 0.08443
#
# Epoch  279
# 	Train Loss: 0.41596 | 	Val Loss: 0.08443
#
# Epoch  280
# 	Train Loss: 0.41568 | 	Val Loss: 0.08442
#
# Epoch  281
# 	Train Loss: 0.41540 | 	Val Loss: 0.08442
#
# Epoch  282
# 	Train Loss: 0.41511 | 	Val Loss: 0.08442
#
# Epoch  283
# 	Train Loss: 0.41481 | 	Val Loss: 0.08442
#
# Epoch  284
# 	Train Loss: 0.41451 | 	Val Loss: 0.08442
#
# Epoch  285
# 	Train Loss: 0.41420 | 	Val Loss: 0.08442
#
# Epoch  286
# 	Train Loss: 0.41388 | 	Val Loss: 0.08441
#
# Epoch  287
# 	Train Loss: 0.41356 | 	Val Loss: 0.08442
#
# Epoch  288
# 	Train Loss: 0.41323 | 	Val Loss: 0.08442
#
# Epoch  289
# 	Train Loss: 0.41289 | 	Val Loss: 0.08442
#
# Epoch  290
# 	Train Loss: 0.41255 | 	Val Loss: 0.08442
#
# Epoch  291
# 	Train Loss: 0.41221 | 	Val Loss: 0.08442
#
# Epoch  292
# 	Train Loss: 0.41186 | 	Val Loss: 0.08443
#
# Epoch  293
# 	Train Loss: 0.41150 | 	Val Loss: 0.08443
#
# Epoch  294
# 	Train Loss: 0.41114 | 	Val Loss: 0.08444
#
# Epoch  295
# 	Train Loss: 0.41078 | 	Val Loss: 0.08444
#
# Epoch  296
# 	Train Loss: 0.41041 | 	Val Loss: 0.08445
#
# Epoch  297
# 	Train Loss: 0.41004 | 	Val Loss: 0.08445
#
# Epoch  298
# 	Train Loss: 0.40967 | 	Val Loss: 0.08446
#
# Epoch  299
# 	Train Loss: 0.40929 | 	Val Loss: 0.08447
#
# Epoch  300
# 	Train Loss: 0.40892 | 	Val Loss: 0.08448
#
# Epoch  301
# 	Train Loss: 0.40854 | 	Val Loss: 0.08449
#
# Epoch  302
# 	Train Loss: 0.40816 | 	Val Loss: 0.08450
#
# Epoch  303
# 	Train Loss: 0.40778 | 	Val Loss: 0.08451
#
# Epoch  304
# 	Train Loss: 0.40741 | 	Val Loss: 0.08452
#
# Epoch  305
# 	Train Loss: 0.40703 | 	Val Loss: 0.08453
#
# Epoch  306
# 	Train Loss: 0.40666 | 	Val Loss: 0.08454
#
# Epoch  307
# 	Train Loss: 0.40628 | 	Val Loss: 0.08455
#
# Epoch  308
# 	Train Loss: 0.40591 | 	Val Loss: 0.08456
#
# Epoch  309
# 	Train Loss: 0.40554 | 	Val Loss: 0.08458
#
# Epoch  310
# 	Train Loss: 0.40518 | 	Val Loss: 0.08459
#
# Epoch  311
# 	Train Loss: 0.40481 | 	Val Loss: 0.08460
#
# Epoch  312
# 	Train Loss: 0.40445 | 	Val Loss: 0.08461
#
# Epoch  313
# 	Train Loss: 0.40410 | 	Val Loss: 0.08462
#
# Epoch  314
# 	Train Loss: 0.40374 | 	Val Loss: 0.08463
#
# Epoch  315
# 	Train Loss: 0.40339 | 	Val Loss: 0.08465
#
# Epoch  316
# 	Train Loss: 0.40304 | 	Val Loss: 0.08466
#
# Epoch  317
# 	Train Loss: 0.40270 | 	Val Loss: 0.08467
#
# Epoch  318
# 	Train Loss: 0.40236 | 	Val Loss: 0.08468
#
# Epoch  319
# 	Train Loss: 0.40202 | 	Val Loss: 0.08469
#
# Epoch  320
# 	Train Loss: 0.40169 | 	Val Loss: 0.08470
#
# Epoch  321
# 	Train Loss: 0.40136 | 	Val Loss: 0.08471
#
# Epoch  322
# 	Train Loss: 0.40103 | 	Val Loss: 0.08472
#
# Epoch  323
# 	Train Loss: 0.40071 | 	Val Loss: 0.08473
#
# Epoch  324
# 	Train Loss: 0.40039 | 	Val Loss: 0.08474
#
# Epoch  325
# 	Train Loss: 0.40007 | 	Val Loss: 0.08475
#
# Epoch  326
# 	Train Loss: 0.39974 | 	Val Loss: 0.08476
#
# Epoch  327
# 	Train Loss: 0.39942 | 	Val Loss: 0.08477
#
# Epoch  328
# 	Train Loss: 0.39911 | 	Val Loss: 0.08478
#
# Epoch  329
# 	Train Loss: 0.39879 | 	Val Loss: 0.08479
#
# Epoch  330
# 	Train Loss: 0.39849 | 	Val Loss: 0.08480
#
# Epoch  331
# 	Train Loss: 0.39820 | 	Val Loss: 0.08480
#
# Epoch  332
# 	Train Loss: 0.39790 | 	Val Loss: 0.08480
#
# Epoch  333
# 	Train Loss: 0.39760 | 	Val Loss: 0.08480
#
# Epoch  334
# 	Train Loss: 0.39726 | 	Val Loss: 0.08481
#
# Epoch  335
# 	Train Loss: 0.39692 | 	Val Loss: 0.08483
#
# Epoch  336
# 	Train Loss: 0.39658 | 	Val Loss: 0.08486
#
# Epoch  337
# 	Train Loss: 0.39627 | 	Val Loss: 0.08490
#
# Epoch  338
# 	Train Loss: 0.39598 | 	Val Loss: 0.08493
#
# Epoch  339
# 	Train Loss: 0.39578 | 	Val Loss: 0.08492
#
# Epoch  340
# 	Train Loss: 0.39572 | 	Val Loss: 0.08486
#
# Epoch  341
# 	Train Loss: 0.39562 | 	Val Loss: 0.08478
#
# Epoch  342
# 	Train Loss: 0.39515 | 	Val Loss: 0.08474
#
# Epoch  343
# 	Train Loss: 0.39449 | 	Val Loss: 0.08479
#
# Epoch  344
# 	Train Loss: 0.39458 | 	Val Loss: 0.08492
#
# Epoch  345
# 	Train Loss: 0.39533 | 	Val Loss: 0.08522
#
# Epoch  346
# 	Train Loss: 0.39473 | 	Val Loss: 0.08564
#
# Epoch  347
# 	Train Loss: 0.39390 | 	Val Loss: 0.08566
#
# Epoch  348
# 	Train Loss: 0.39966 | 	Val Loss: 0.08476
#
# Epoch  349
# 	Train Loss: 0.40715 | 	Val Loss: 0.08458
#
# Epoch  350
# 	Train Loss: 0.39867 | 	Val Loss: 0.08440
#
# Epoch  351
# 	Train Loss: 0.41716 | 	Val Loss: 0.08682
#
# Epoch  352
# 	Train Loss: 0.41061 | 	Val Loss: 0.08617
#
# Epoch  353
# 	Train Loss: 0.41890 | 	Val Loss: 0.08673
#
# Epoch  354
# 	Train Loss: 0.40878 | 	Val Loss: 0.08484
#
# Epoch  355
# 	Train Loss: 0.41387 | 	Val Loss: 0.08753
#
# Epoch  356
# 	Train Loss: 0.40641 | 	Val Loss: 0.08571
#
# Epoch  357
# 	Train Loss: 0.39981 | 	Val Loss: 0.08485
#
# Epoch  358
# 	Train Loss: 0.39720 | 	Val Loss: 0.08477
#
# Epoch  359
# 	Train Loss: 0.39590 | 	Val Loss: 0.08393
#
# Epoch  360
# 	Train Loss: 0.39606 | 	Val Loss: 0.08495
#
# Epoch  361
# 	Train Loss: 0.40285 | 	Val Loss: 0.08455
#
# Epoch  362
# 	Train Loss: 0.40177 | 	Val Loss: 0.08521
#
# Epoch  363
# 	Train Loss: 0.40826 | 	Val Loss: 0.08471
#
# Epoch  364
# 	Train Loss: 0.40014 | 	Val Loss: 0.08385
#
# Epoch  365
# 	Train Loss: 0.39796 | 	Val Loss: 0.08430
#
# Epoch  366
# 	Train Loss: 0.39542 | 	Val Loss: 0.08376
#
# Epoch  367
# 	Train Loss: 0.39434 | 	Val Loss: 0.08468
#
# Epoch  368
# 	Train Loss: 0.39712 | 	Val Loss: 0.08437
#
# Epoch  369
# 	Train Loss: 0.39440 | 	Val Loss: 0.08431
#
# Epoch  370
# 	Train Loss: 0.39539 | 	Val Loss: 0.08422
#
# Epoch  371
# 	Train Loss: 0.39122 | 	Val Loss: 0.08403
#
# Epoch  372
# 	Train Loss: 0.38969 | 	Val Loss: 0.08440
#
# Epoch  373
# 	Train Loss: 0.38836 | 	Val Loss: 0.08407
#
# Epoch  374
# 	Train Loss: 0.38710 | 	Val Loss: 0.08449
#
# Epoch  375
# 	Train Loss: 0.38753 | 	Val Loss: 0.08424
#
# Epoch  376
# 	Train Loss: 0.38633 | 	Val Loss: 0.08445
#
# Epoch  377
# 	Train Loss: 0.38702 | 	Val Loss: 0.08435
#
# Epoch  378
# 	Train Loss: 0.38566 | 	Val Loss: 0.08445
#
# Epoch  379
# 	Train Loss: 0.38584 | 	Val Loss: 0.08444
#
# Epoch  380
# 	Train Loss: 0.38476 | 	Val Loss: 0.08446
#
# Epoch  381
# 	Train Loss: 0.38444 | 	Val Loss: 0.08456
#
# Epoch  382
# 	Train Loss: 0.38414 | 	Val Loss: 0.08449
#
# Epoch  383
# 	Train Loss: 0.38356 | 	Val Loss: 0.08471
#
# Epoch  384
# 	Train Loss: 0.38413 | 	Val Loss: 0.08454
#
# Epoch  385
# 	Train Loss: 0.38320 | 	Val Loss: 0.08485
#
# Epoch  386
# 	Train Loss: 0.38401 | 	Val Loss: 0.08461
#
# Epoch  387
# 	Train Loss: 0.38264 | 	Val Loss: 0.08491
#
# Epoch  388
# 	Train Loss: 0.38286 | 	Val Loss: 0.08469
#
# Epoch  389
# 	Train Loss: 0.38177 | 	Val Loss: 0.08485
#
# Epoch  390
# 	Train Loss: 0.38144 | 	Val Loss: 0.08487
#
# Epoch  391
# 	Train Loss: 0.38190 | 	Val Loss: 0.08476
#
# Epoch  392
# 	Train Loss: 0.38144 | 	Val Loss: 0.08523
#
# Epoch  393
# 	Train Loss: 0.38388 | 	Val Loss: 0.08482
#
# Epoch  394
# 	Train Loss: 0.38237 | 	Val Loss: 0.08562
#
# Epoch  395
# 	Train Loss: 0.38487 | 	Val Loss: 0.08493
#
# Epoch  396
# 	Train Loss: 0.38176 | 	Val Loss: 0.08559
#
# Epoch  397
# 	Train Loss: 0.38225 | 	Val Loss: 0.08495
#
# Epoch  398
# 	Train Loss: 0.38029 | 	Val Loss: 0.08514
#
# Epoch  399
# 	Train Loss: 0.38021 | 	Val Loss: 0.08520
#
# Epoch  400
# 	Train Loss: 0.38268 | 	Val Loss: 0.08495
#
# Epoch  401
# 	Train Loss: 0.38323 | 	Val Loss: 0.08593
#
# Epoch  402
# 	Train Loss: 0.39018 | 	Val Loss: 0.08526
#
# Epoch  403
# 	Train Loss: 0.38613 | 	Val Loss: 0.08633
#
# Epoch  404
# 	Train Loss: 0.39009 | 	Val Loss: 0.08519
#
# Epoch  405
# 	Train Loss: 0.38285 | 	Val Loss: 0.08543
#
# Epoch  406
# 	Train Loss: 0.38199 | 	Val Loss: 0.08516
#
# Epoch  407
# 	Train Loss: 0.38020 | 	Val Loss: 0.08490
#
# Epoch  408
# 	Train Loss: 0.37996 | 	Val Loss: 0.08555
#
# Epoch  409
# 	Train Loss: 0.38309 | 	Val Loss: 0.08515
#
# Epoch  410
# 	Train Loss: 0.38116 | 	Val Loss: 0.08569
#
# Epoch  411
# 	Train Loss: 0.38410 | 	Val Loss: 0.08525
#
# Epoch  412
# 	Train Loss: 0.37812 | 	Val Loss: 0.08547
#
# Epoch  413
# 	Train Loss: 0.37775 | 	Val Loss: 0.08534
#
# Epoch  414
# 	Train Loss: 0.37375 | 	Val Loss: 0.08528
#
# Epoch  415
# 	Train Loss: 0.37283 | 	Val Loss: 0.08561
#
# Epoch  416
# 	Train Loss: 0.37221 | 	Val Loss: 0.08537
#
# Epoch  417
# 	Train Loss: 0.37136 | 	Val Loss: 0.08571
#
# Epoch  418
# 	Train Loss: 0.37194 | 	Val Loss: 0.08556
#
# Epoch  419
# 	Train Loss: 0.37045 | 	Val Loss: 0.08582
#
# Epoch  420
# 	Train Loss: 0.37116 | 	Val Loss: 0.08570
#
# Epoch  421
# 	Train Loss: 0.36915 | 	Val Loss: 0.08593
#
# Epoch  422
# 	Train Loss: 0.36953 | 	Val Loss: 0.08582
#
# Epoch  423
# 	Train Loss: 0.36765 | 	Val Loss: 0.08602
#
# Epoch  424
# 	Train Loss: 0.36764 | 	Val Loss: 0.08596
#
# Epoch  425
# 	Train Loss: 0.36648 | 	Val Loss: 0.08610
#
# Epoch  426
# 	Train Loss: 0.36611 | 	Val Loss: 0.08613
#
# Epoch  427
# 	Train Loss: 0.36586 | 	Val Loss: 0.08617
#
# Epoch  428
# 	Train Loss: 0.36504 | 	Val Loss: 0.08634
#
# Epoch  429
# 	Train Loss: 0.36557 | 	Val Loss: 0.08623
#
# Epoch  430
# 	Train Loss: 0.36415 | 	Val Loss: 0.08658
#
# Epoch  431
# 	Train Loss: 0.36507 | 	Val Loss: 0.08630
#
# Epoch  432
# 	Train Loss: 0.36307 | 	Val Loss: 0.08678
#
# Epoch  433
# 	Train Loss: 0.36385 | 	Val Loss: 0.08642
#
# Epoch  434
# 	Train Loss: 0.36177 | 	Val Loss: 0.08690
#
# Epoch  435
# 	Train Loss: 0.36206 | 	Val Loss: 0.08659
#
# Epoch  436
# 	Train Loss: 0.36064 | 	Val Loss: 0.08693
#
# Epoch  437
# 	Train Loss: 0.36038 | 	Val Loss: 0.08682
#
# Epoch  438
# 	Train Loss: 0.36013 | 	Val Loss: 0.08689
#
# Epoch  439
# 	Train Loss: 0.35928 | 	Val Loss: 0.08713
#
# Epoch  440
# 	Train Loss: 0.36030 | 	Val Loss: 0.08687
#
# Epoch  441
# 	Train Loss: 0.35861 | 	Val Loss: 0.08750
#
# Epoch  442
# 	Train Loss: 0.36051 | 	Val Loss: 0.08691
#
# Epoch  443
# 	Train Loss: 0.35783 | 	Val Loss: 0.08783
#
# Epoch  444
# 	Train Loss: 0.35975 | 	Val Loss: 0.08705
#
# Epoch  445
# 	Train Loss: 0.35654 | 	Val Loss: 0.08798
#
# Epoch  446
# 	Train Loss: 0.35780 | 	Val Loss: 0.08726
#
# Epoch  447
# 	Train Loss: 0.35496 | 	Val Loss: 0.08795
#
# Epoch  448
# 	Train Loss: 0.35545 | 	Val Loss: 0.08752
#
# Epoch  449
# 	Train Loss: 0.35362 | 	Val Loss: 0.08785
#
# Epoch  450
# 	Train Loss: 0.35346 | 	Val Loss: 0.08783
#
# Epoch  451
# 	Train Loss: 0.35288 | 	Val Loss: 0.08776
#
# Epoch  452
# 	Train Loss: 0.35204 | 	Val Loss: 0.08821
#
# Epoch  453
# 	Train Loss: 0.35271 | 	Val Loss: 0.08772
#
# Epoch  454
# 	Train Loss: 0.35108 | 	Val Loss: 0.08865
#
# Epoch  455
# 	Train Loss: 0.35292 | 	Val Loss: 0.08774
#
# Epoch  456
# 	Train Loss: 0.35051 | 	Val Loss: 0.08905
#
# Epoch  457
# 	Train Loss: 0.35340 | 	Val Loss: 0.08779
#
# Epoch  458
# 	Train Loss: 0.35035 | 	Val Loss: 0.08937
#
# Epoch  459
# 	Train Loss: 0.35425 | 	Val Loss: 0.08789
#
# Epoch  460
# 	Train Loss: 0.35067 | 	Val Loss: 0.08958
#
# Epoch  461
# 	Train Loss: 0.35540 | 	Val Loss: 0.08806
#
# Epoch  462
# 	Train Loss: 0.35120 | 	Val Loss: 0.08965
#
# Epoch  463
# 	Train Loss: 0.35615 | 	Val Loss: 0.08836
#
# Epoch  464
# 	Train Loss: 0.35120 | 	Val Loss: 0.08955
#
# Epoch  465
# 	Train Loss: 0.35553 | 	Val Loss: 0.08880
#
# Epoch  466
# 	Train Loss: 0.35000 | 	Val Loss: 0.08936
#
# Epoch  467
# 	Train Loss: 0.35332 | 	Val Loss: 0.08923
#
# Epoch  468
# 	Train Loss: 0.34789 | 	Val Loss: 0.08925
#
# Epoch  469
# 	Train Loss: 0.35036 | 	Val Loss: 0.08952
#
# Epoch  470
# 	Train Loss: 0.34568 | 	Val Loss: 0.08929
#
# Epoch  471
# 	Train Loss: 0.34760 | 	Val Loss: 0.08970
#
# Epoch  472
# 	Train Loss: 0.34393 | 	Val Loss: 0.08938
#
# Epoch  473
# 	Train Loss: 0.34550 | 	Val Loss: 0.08988
#
# Epoch  474
# 	Train Loss: 0.34292 | 	Val Loss: 0.08944
#
# Epoch  475
# 	Train Loss: 0.34438 | 	Val Loss: 0.09017
#
# Epoch  476
# 	Train Loss: 0.34325 | 	Val Loss: 0.08940
#
# Epoch  477
# 	Train Loss: 0.34516 | 	Val Loss: 0.09063
#
# Epoch  478
# 	Train Loss: 0.34641 | 	Val Loss: 0.08923
#
# Epoch  479
# 	Train Loss: 0.34973 | 	Val Loss: 0.09119
#
# Epoch  480
# 	Train Loss: 0.35331 | 	Val Loss: 0.08918
#
# Epoch  481
# 	Train Loss: 0.35619 | 	Val Loss: 0.09126
#
# Epoch  482
# 	Train Loss: 0.35600 | 	Val Loss: 0.09000
#
# Epoch  483
# 	Train Loss: 0.35167 | 	Val Loss: 0.09032
#
# Epoch  484
# 	Train Loss: 0.34666 | 	Val Loss: 0.09134
#
# Epoch  485
# 	Train Loss: 0.34103 | 	Val Loss: 0.08983
#
# Epoch  486
# 	Train Loss: 0.33844 | 	Val Loss: 0.09167
#
# Epoch  487
# 	Train Loss: 0.33681 | 	Val Loss: 0.09037
#
# Epoch  488
# 	Train Loss: 0.33579 | 	Val Loss: 0.09137
#
# Epoch  489
# 	Train Loss: 0.33560 | 	Val Loss: 0.09090
#
# Epoch  490
# 	Train Loss: 0.33464 | 	Val Loss: 0.09117
#
# Epoch  491
# 	Train Loss: 0.33470 | 	Val Loss: 0.09119
#
# Epoch  492
# 	Train Loss: 0.33368 | 	Val Loss: 0.09128
#
# Epoch  493
# 	Train Loss: 0.33400 | 	Val Loss: 0.09132
#
# Epoch  494
# 	Train Loss: 0.33280 | 	Val Loss: 0.09151
#
# Epoch  495
# 	Train Loss: 0.33363 | 	Val Loss: 0.09135
#
# Epoch  496
# 	Train Loss: 0.33208 | 	Val Loss: 0.09180
#
# Epoch  497
# 	Train Loss: 0.33384 | 	Val Loss: 0.09135
#
# Epoch  498
# 	Train Loss: 0.33186 | 	Val Loss: 0.09212
#
# Epoch  499
# 	Train Loss: 0.33540 | 	Val Loss: 0.09131
#
# Epoch  500
# 	Train Loss: 0.33306 | 	Val Loss: 0.09252
#
# Epoch  501
# 	Train Loss: 0.34008 | 	Val Loss: 0.09118
#
# Epoch  502
# 	Train Loss: 0.33759 | 	Val Loss: 0.09297
#
# Epoch  503
# 	Train Loss: 0.35018 | 	Val Loss: 0.09110
#
# Epoch  504
# 	Train Loss: 0.34646 | 	Val Loss: 0.09307
#
# Epoch  505
# 	Train Loss: 0.36231 | 	Val Loss: 0.09151
#
# Epoch  506
# 	Train Loss: 0.35203 | 	Val Loss: 0.09206
#
# Epoch  507
# 	Train Loss: 0.36032 | 	Val Loss: 0.09264
#
# Epoch  508
# 	Train Loss: 0.34401 | 	Val Loss: 0.09102
#
# Epoch  509
# 	Train Loss: 0.34232 | 	Val Loss: 0.09338
#
# Epoch  510
# 	Train Loss: 0.33250 | 	Val Loss: 0.09142
#
# Epoch  511
# 	Train Loss: 0.33016 | 	Val Loss: 0.09292
#
# Epoch  512
# 	Train Loss: 0.32743 | 	Val Loss: 0.09212
#
# Epoch  513
# 	Train Loss: 0.32635 | 	Val Loss: 0.09250
#
# Epoch  514
# 	Train Loss: 0.32596 | 	Val Loss: 0.09244
#
# Epoch  515
# 	Train Loss: 0.32507 | 	Val Loss: 0.09257
#
# Epoch  516
# 	Train Loss: 0.32515 | 	Val Loss: 0.09255
#
# Epoch  517
# 	Train Loss: 0.32409 | 	Val Loss: 0.09280
#
# Epoch  518
# 	Train Loss: 0.32435 | 	Val Loss: 0.09262
#
# Epoch  519
# 	Train Loss: 0.32320 | 	Val Loss: 0.09304
#
# Epoch  520
# 	Train Loss: 0.32360 | 	Val Loss: 0.09271
#
# Epoch  521
# 	Train Loss: 0.32242 | 	Val Loss: 0.09325
#
# Epoch  522
# 	Train Loss: 0.32298 | 	Val Loss: 0.09282
#
# Epoch  523
# 	Train Loss: 0.32174 | 	Val Loss: 0.09345
#
# Epoch  524
# 	Train Loss: 0.32259 | 	Val Loss: 0.09290
#
# Epoch  525
# 	Train Loss: 0.32124 | 	Val Loss: 0.09368
#
# Epoch  526
# 	Train Loss: 0.32255 | 	Val Loss: 0.09293
#
# Epoch  527
# 	Train Loss: 0.32108 | 	Val Loss: 0.09395
#
# Epoch  528
# 	Train Loss: 0.32304 | 	Val Loss: 0.09291
#
# Epoch  529
# 	Train Loss: 0.32142 | 	Val Loss: 0.09425
#
# Epoch  530
# 	Train Loss: 0.32402 | 	Val Loss: 0.09291
#
# Epoch  531
# 	Train Loss: 0.32209 | 	Val Loss: 0.09448
#
# Epoch  532
# 	Train Loss: 0.32486 | 	Val Loss: 0.09301
#
# Epoch  533
# 	Train Loss: 0.32221 | 	Val Loss: 0.09454
#
# Epoch  534
# 	Train Loss: 0.32438 | 	Val Loss: 0.09329
#
# Epoch  535
# 	Train Loss: 0.32082 | 	Val Loss: 0.09442
#
# Epoch  536
# 	Train Loss: 0.32224 | 	Val Loss: 0.09366
#
# Epoch  537
# 	Train Loss: 0.31849 | 	Val Loss: 0.09429
#
# Epoch  538
# 	Train Loss: 0.31959 | 	Val Loss: 0.09394
#
# Epoch  539
# 	Train Loss: 0.31646 | 	Val Loss: 0.09428
#
# Epoch  540
# 	Train Loss: 0.31744 | 	Val Loss: 0.09408
#
# Epoch  541
# 	Train Loss: 0.31510 | 	Val Loss: 0.09435
#
# Epoch  542
# 	Train Loss: 0.31589 | 	Val Loss: 0.09417
#
# Epoch  543
# 	Train Loss: 0.31422 | 	Val Loss: 0.09440
#
# Epoch  544
# 	Train Loss: 0.31470 | 	Val Loss: 0.09428
#
# Epoch  545
# 	Train Loss: 0.31370 | 	Val Loss: 0.09441
#
# Epoch  546
# 	Train Loss: 0.31374 | 	Val Loss: 0.09446
#
# Epoch  547
# 	Train Loss: 0.31369 | 	Val Loss: 0.09432
#
# Epoch  548
# 	Train Loss: 0.31320 | 	Val Loss: 0.09475
#
# Epoch  549
# 	Train Loss: 0.31488 | 	Val Loss: 0.09410
#
# Epoch  550
# 	Train Loss: 0.31405 | 	Val Loss: 0.09520
#
# Epoch  551
# 	Train Loss: 0.31891 | 	Val Loss: 0.09375
#
# Epoch  552
# 	Train Loss: 0.31830 | 	Val Loss: 0.09578
#
# Epoch  553
# 	Train Loss: 0.32656 | 	Val Loss: 0.09349
#
# Epoch  554
# 	Train Loss: 0.32403 | 	Val Loss: 0.09591
#
# Epoch  555
# 	Train Loss: 0.32961 | 	Val Loss: 0.09402
#
# Epoch  556
# 	Train Loss: 0.32025 | 	Val Loss: 0.09490
#
# Epoch  557
# 	Train Loss: 0.32310 | 	Val Loss: 0.09529
#
# Epoch  558
# 	Train Loss: 0.31480 | 	Val Loss: 0.09409
#
# Epoch  559
# 	Train Loss: 0.32000 | 	Val Loss: 0.09571
#
# Epoch  560
# 	Train Loss: 0.31540 | 	Val Loss: 0.09418
#
# Epoch  561
# 	Train Loss: 0.32135 | 	Val Loss: 0.09549
#
# Epoch  562
# 	Train Loss: 0.31655 | 	Val Loss: 0.09438
#
# Epoch  563
# 	Train Loss: 0.31979 | 	Val Loss: 0.09527
#
# Epoch  564
# 	Train Loss: 0.31352 | 	Val Loss: 0.09471
#
# Epoch  565
# 	Train Loss: 0.31306 | 	Val Loss: 0.09490
#
# Epoch  566
# 	Train Loss: 0.30774 | 	Val Loss: 0.09509
#
# Epoch  567
# 	Train Loss: 0.30655 | 	Val Loss: 0.09478
#
# Epoch  568
# 	Train Loss: 0.30421 | 	Val Loss: 0.09525
#
# Epoch  569
# 	Train Loss: 0.30362 | 	Val Loss: 0.09498
#
# Epoch  570
# 	Train Loss: 0.30286 | 	Val Loss: 0.09516
#
# Epoch  571
# 	Train Loss: 0.30245 | 	Val Loss: 0.09515
#
# Epoch  572
# 	Train Loss: 0.30197 | 	Val Loss: 0.09521
#
# Epoch  573
# 	Train Loss: 0.30165 | 	Val Loss: 0.09517
#
# Epoch  574
# 	Train Loss: 0.30114 | 	Val Loss: 0.09530
#
# Epoch  575
# 	Train Loss: 0.30089 | 	Val Loss: 0.09525
#
# Epoch  576
# 	Train Loss: 0.30031 | 	Val Loss: 0.09534
#
# Epoch  577
# 	Train Loss: 0.30023 | 	Val Loss: 0.09526
#
# Epoch  578
# 	Train Loss: 0.29947 | 	Val Loss: 0.09549
#
# Epoch  579
# 	Train Loss: 0.29969 | 	Val Loss: 0.09522
#
# Epoch  580
# 	Train Loss: 0.29872 | 	Val Loss: 0.09560
#
# Epoch  581
# 	Train Loss: 0.29938 | 	Val Loss: 0.09519
#
# Epoch  582
# 	Train Loss: 0.29817 | 	Val Loss: 0.09582
#
# Epoch  583
# 	Train Loss: 0.29970 | 	Val Loss: 0.09498
#
# Epoch  584
# 	Train Loss: 0.29825 | 	Val Loss: 0.09617
#
# Epoch  585
# 	Train Loss: 0.30129 | 	Val Loss: 0.09474
#
# Epoch  586
# 	Train Loss: 0.29988 | 	Val Loss: 0.09659
#
# Epoch  587
# 	Train Loss: 0.30508 | 	Val Loss: 0.09433
#
# Epoch  588
# 	Train Loss: 0.30371 | 	Val Loss: 0.09718
#
# Epoch  589
# 	Train Loss: 0.30932 | 	Val Loss: 0.09412
#
# Epoch  590
# 	Train Loss: 0.30560 | 	Val Loss: 0.09714
#
# Epoch  591
# 	Train Loss: 0.30762 | 	Val Loss: 0.09462
#
# Epoch  592
# 	Train Loss: 0.30085 | 	Val Loss: 0.09652
#
# Epoch  593
# 	Train Loss: 0.30099 | 	Val Loss: 0.09536
#
# Epoch  594
# 	Train Loss: 0.29599 | 	Val Loss: 0.09584
#
# Epoch  595
# 	Train Loss: 0.29647 | 	Val Loss: 0.09583
#
# Epoch  596
# 	Train Loss: 0.29427 | 	Val Loss: 0.09578
#
# Epoch  597
# 	Train Loss: 0.29446 | 	Val Loss: 0.09560
#
# Epoch  598
# 	Train Loss: 0.29381 | 	Val Loss: 0.09581
#
# Epoch  599
# 	Train Loss: 0.29352 | 	Val Loss: 0.09593
#
# Epoch  600
# 	Train Loss: 0.29426 | 	Val Loss: 0.09564
#
# Epoch  601
# 	Train Loss: 0.29322 | 	Val Loss: 0.09565
#
# Epoch  602
# 	Train Loss: 0.29541 | 	Val Loss: 0.09581
#
# Epoch  603
# 	Train Loss: 0.29395 | 	Val Loss: 0.09626
#
# Epoch  604
# 	Train Loss: 0.29890 | 	Val Loss: 0.09499
#
# Epoch  605
# 	Train Loss: 0.29673 | 	Val Loss: 0.09621
#
# Epoch  606
# 	Train Loss: 0.30408 | 	Val Loss: 0.09561
#
# Epoch  607
# 	Train Loss: 0.30152 | 	Val Loss: 0.09658
#
# Epoch  608
# 	Train Loss: 0.30889 | 	Val Loss: 0.09422
#
# Epoch  609
# 	Train Loss: 0.30288 | 	Val Loss: 0.09680
#
# Epoch  610
# 	Train Loss: 0.30483 | 	Val Loss: 0.09631
#
# Epoch  611
# 	Train Loss: 0.29933 | 	Val Loss: 0.09499
#
# Epoch  612
# 	Train Loss: 0.29996 | 	Val Loss: 0.09547
#
# Epoch  613
# 	Train Loss: 0.29511 | 	Val Loss: 0.09638
#
# Epoch  614
# 	Train Loss: 0.29767 | 	Val Loss: 0.09585
#
# Epoch  615
# 	Train Loss: 0.29224 | 	Val Loss: 0.09425
#
# Epoch  616
# 	Train Loss: 0.29884 | 	Val Loss: 0.09745
#
# Epoch  617
# 	Train Loss: 0.29520 | 	Val Loss: 0.09535
#
# Epoch  618
# 	Train Loss: 0.29655 | 	Val Loss: 0.09493
#
# Epoch  619
# 	Train Loss: 0.29195 | 	Val Loss: 0.09586
#
# Epoch  620
# 	Train Loss: 0.29095 | 	Val Loss: 0.09580
#
# Epoch  621
# 	Train Loss: 0.28864 | 	Val Loss: 0.09474
#
# Epoch  622
# 	Train Loss: 0.29096 | 	Val Loss: 0.09664
#
# Epoch  623
# 	Train Loss: 0.28868 | 	Val Loss: 0.09522
#
# Epoch  624
# 	Train Loss: 0.28833 | 	Val Loss: 0.09543
#
# Epoch  625
# 	Train Loss: 0.28591 | 	Val Loss: 0.09554
#
# Epoch  626
# 	Train Loss: 0.28516 | 	Val Loss: 0.09574
#
# Epoch  627
# 	Train Loss: 0.28436 | 	Val Loss: 0.09517
#
# Epoch  628
# 	Train Loss: 0.28419 | 	Val Loss: 0.09611
#
# Epoch  629
# 	Train Loss: 0.28373 | 	Val Loss: 0.09528
#
# Epoch  630
# 	Train Loss: 0.28326 | 	Val Loss: 0.09582
#
# Epoch  631
# 	Train Loss: 0.28289 | 	Val Loss: 0.09542
#
# Epoch  632
# 	Train Loss: 0.28226 | 	Val Loss: 0.09601
#
# Epoch  633
# 	Train Loss: 0.28224 | 	Val Loss: 0.09521
#
# Epoch  634
# 	Train Loss: 0.28172 | 	Val Loss: 0.09619
#
# Epoch  635
# 	Train Loss: 0.28164 | 	Val Loss: 0.09530
#
# Epoch  636
# 	Train Loss: 0.28117 | 	Val Loss: 0.09601
#
# Epoch  637
# 	Train Loss: 0.28103 | 	Val Loss: 0.09539
#
# Epoch  638
# 	Train Loss: 0.28076 | 	Val Loss: 0.09614
#
# Epoch  639
# 	Train Loss: 0.28044 | 	Val Loss: 0.09534
#
# Epoch  640
# 	Train Loss: 0.28111 | 	Val Loss: 0.09596
#
# Epoch  641
# 	Train Loss: 0.28059 | 	Val Loss: 0.09587
#
# Epoch  642
# 	Train Loss: 0.28451 | 	Val Loss: 0.09527
#
# Epoch  643
# 	Train Loss: 0.28609 | 	Val Loss: 0.09669
#
# Epoch  644
# 	Train Loss: 0.29806 | 	Val Loss: 0.09438
#
# Epoch  645
# 	Train Loss: 0.30705 | 	Val Loss: 0.09796
#
# Epoch  646
# 	Train Loss: 0.31048 | 	Val Loss: 0.09349
#
# Epoch  647
# 	Train Loss: 0.30138 | 	Val Loss: 0.09813
#
# Epoch  648
# 	Train Loss: 0.28816 | 	Val Loss: 0.09541
#
# Epoch  649
# 	Train Loss: 0.28107 | 	Val Loss: 0.09522
#
# Epoch  650
# 	Train Loss: 0.27889 | 	Val Loss: 0.09682
#
# Epoch  651
# 	Train Loss: 0.28007 | 	Val Loss: 0.09535
#
# Epoch  652
# 	Train Loss: 0.27751 | 	Val Loss: 0.09558
#
# Epoch  653
# 	Train Loss: 0.28070 | 	Val Loss: 0.09612
#
# Epoch  654
# 	Train Loss: 0.27779 | 	Val Loss: 0.09601
#
# Epoch  655
# 	Train Loss: 0.27953 | 	Val Loss: 0.09514
#
# Epoch  656
# 	Train Loss: 0.27671 | 	Val Loss: 0.09633
#
# Epoch  657
# 	Train Loss: 0.27812 | 	Val Loss: 0.09580
#
# Epoch  658
# 	Train Loss: 0.27623 | 	Val Loss: 0.09539
#
# Epoch  659
# 	Train Loss: 0.27927 | 	Val Loss: 0.09593
#
# Epoch  660
# 	Train Loss: 0.27567 | 	Val Loss: 0.09631
#
# Epoch  661
# 	Train Loss: 0.27888 | 	Val Loss: 0.09485
#
# Epoch  662
# 	Train Loss: 0.27548 | 	Val Loss: 0.09632
#
# Epoch  663
# 	Train Loss: 0.27844 | 	Val Loss: 0.09582
#
# Epoch  664
# 	Train Loss: 0.27665 | 	Val Loss: 0.09578
#
# Epoch  665
# 	Train Loss: 0.28048 | 	Val Loss: 0.09496
#
# Epoch  666
# 	Train Loss: 0.27692 | 	Val Loss: 0.09737
#
# Epoch  667
# 	Train Loss: 0.28241 | 	Val Loss: 0.09445
#
# Epoch  668
# 	Train Loss: 0.27705 | 	Val Loss: 0.09641
#
# Epoch  669
# 	Train Loss: 0.28231 | 	Val Loss: 0.09563
#
# Epoch  670
# 	Train Loss: 0.27880 | 	Val Loss: 0.09651
#
# Epoch  671
# 	Train Loss: 0.28104 | 	Val Loss: 0.09393
#
# Epoch  672
# 	Train Loss: 0.27786 | 	Val Loss: 0.09819
#
# Epoch  673
# 	Train Loss: 0.27955 | 	Val Loss: 0.09460
#
# Epoch  674
# 	Train Loss: 0.27532 | 	Val Loss: 0.09566
#
# Epoch  675
# 	Train Loss: 0.28093 | 	Val Loss: 0.09619
#
# Epoch  676
# 	Train Loss: 0.27813 | 	Val Loss: 0.09598
#
# Epoch  677
# 	Train Loss: 0.27834 | 	Val Loss: 0.09449
#
# Epoch  678
# 	Train Loss: 0.27689 | 	Val Loss: 0.09643
#
# Epoch  679
# 	Train Loss: 0.27697 | 	Val Loss: 0.09569
#
# Epoch  680
# 	Train Loss: 0.27894 | 	Val Loss: 0.09416
#
# Epoch  681
# 	Train Loss: 0.28385 | 	Val Loss: 0.09799
#
# Epoch  682
# 	Train Loss: 0.28809 | 	Val Loss: 0.09370
#
# Epoch  683
# 	Train Loss: 0.28778 | 	Val Loss: 0.09752
#
# Epoch  684
# 	Train Loss: 0.28704 | 	Val Loss: 0.09330
#
# Epoch  685
# 	Train Loss: 0.28286 | 	Val Loss: 0.09771
#
# Epoch  686
# 	Train Loss: 0.28038 | 	Val Loss: 0.09369
#
# Epoch  687
# 	Train Loss: 0.27319 | 	Val Loss: 0.09697
#
# Epoch  688
# 	Train Loss: 0.27203 | 	Val Loss: 0.09470
#
# Epoch  689
# 	Train Loss: 0.26796 | 	Val Loss: 0.09539
#
# Epoch  690
# 	Train Loss: 0.26925 | 	Val Loss: 0.09569
#
# Epoch  691
# 	Train Loss: 0.26756 | 	Val Loss: 0.09501
#
# Epoch  692
# 	Train Loss: 0.26886 | 	Val Loss: 0.09594
#
# Epoch  693
# 	Train Loss: 0.26704 | 	Val Loss: 0.09517
#
# Epoch  694
# 	Train Loss: 0.26810 | 	Val Loss: 0.09563
#
# Epoch  695
# 	Train Loss: 0.26619 | 	Val Loss: 0.09550
#
# Epoch  696
# 	Train Loss: 0.26769 | 	Val Loss: 0.09540
#
# Epoch  697
# 	Train Loss: 0.26570 | 	Val Loss: 0.09576
#
# Epoch  698
# 	Train Loss: 0.26806 | 	Val Loss: 0.09529
#
# Epoch  699
# 	Train Loss: 0.26584 | 	Val Loss: 0.09596
#
# Epoch  700
# 	Train Loss: 0.26959 | 	Val Loss: 0.09515
#
# Epoch  701
# 	Train Loss: 0.26715 | 	Val Loss: 0.09627
#
# Epoch  702
# 	Train Loss: 0.27276 | 	Val Loss: 0.09488
#
# Epoch  703
# 	Train Loss: 0.27012 | 	Val Loss: 0.09667
#
# Epoch  704
# 	Train Loss: 0.27642 | 	Val Loss: 0.09467
#
# Epoch  705
# 	Train Loss: 0.27225 | 	Val Loss: 0.09687
#
# Epoch  706
# 	Train Loss: 0.27621 | 	Val Loss: 0.09481
#
# Epoch  707
# 	Train Loss: 0.26968 | 	Val Loss: 0.09659
#
# Epoch  708
# 	Train Loss: 0.27241 | 	Val Loss: 0.09525
#
# Epoch  709
# 	Train Loss: 0.26683 | 	Val Loss: 0.09617
#
# Epoch  710
# 	Train Loss: 0.26975 | 	Val Loss: 0.09555
#
# Epoch  711
# 	Train Loss: 0.26586 | 	Val Loss: 0.09596
#
# Epoch  712
# 	Train Loss: 0.26811 | 	Val Loss: 0.09572
#
# Epoch  713
# 	Train Loss: 0.26513 | 	Val Loss: 0.09577
#
# Epoch  714
# 	Train Loss: 0.26654 | 	Val Loss: 0.09595
#
# Epoch  715
# 	Train Loss: 0.26428 | 	Val Loss: 0.09557
#
# Epoch  716
# 	Train Loss: 0.26488 | 	Val Loss: 0.09612
#
# Epoch  717
# 	Train Loss: 0.26313 | 	Val Loss: 0.09547
#
# Epoch  718
# 	Train Loss: 0.26316 | 	Val Loss: 0.09618
#
# Epoch  719
# 	Train Loss: 0.26193 | 	Val Loss: 0.09543
#
# Epoch  720
# 	Train Loss: 0.26193 | 	Val Loss: 0.09626
#
# Epoch  721
# 	Train Loss: 0.26107 | 	Val Loss: 0.09542
#
# Epoch  722
# 	Train Loss: 0.26162 | 	Val Loss: 0.09626
#
# Epoch  723
# 	Train Loss: 0.26083 | 	Val Loss: 0.09557
#
# Epoch  724
# 	Train Loss: 0.26322 | 	Val Loss: 0.09602
#
# Epoch  725
# 	Train Loss: 0.26308 | 	Val Loss: 0.09600
#
# Epoch  726
# 	Train Loss: 0.27013 | 	Val Loss: 0.09548
#
# Epoch  727
# 	Train Loss: 0.27362 | 	Val Loss: 0.09679
#
# Epoch  728
# 	Train Loss: 0.28303 | 	Val Loss: 0.09469
#
# Epoch  729
# 	Train Loss: 0.28538 | 	Val Loss: 0.09761
#
# Epoch  730
# 	Train Loss: 0.27743 | 	Val Loss: 0.09482
#
# Epoch  731
# 	Train Loss: 0.26602 | 	Val Loss: 0.09654
#
# Epoch  732
# 	Train Loss: 0.26413 | 	Val Loss: 0.09590
#
# Epoch  733
# 	Train Loss: 0.26089 | 	Val Loss: 0.09555
#
# Epoch  734
# 	Train Loss: 0.26183 | 	Val Loss: 0.09586
#
# Epoch  735
# 	Train Loss: 0.26049 | 	Val Loss: 0.09612
#
# Epoch  736
# 	Train Loss: 0.26138 | 	Val Loss: 0.09550
#
# Epoch  737
# 	Train Loss: 0.25988 | 	Val Loss: 0.09606
#
# Epoch  738
# 	Train Loss: 0.26124 | 	Val Loss: 0.09605
#
# Epoch  739
# 	Train Loss: 0.25996 | 	Val Loss: 0.09540
#
# Epoch  740
# 	Train Loss: 0.26348 | 	Val Loss: 0.09606
#
# Epoch  741
# 	Train Loss: 0.26195 | 	Val Loss: 0.09614
#
# Epoch  742
# 	Train Loss: 0.26864 | 	Val Loss: 0.09505
#
# Epoch  743
# 	Train Loss: 0.26848 | 	Val Loss: 0.09700
#
# Epoch  744
# 	Train Loss: 0.27266 | 	Val Loss: 0.09510
#
# Epoch  745
# 	Train Loss: 0.26910 | 	Val Loss: 0.09632
#
# Epoch  746
# 	Train Loss: 0.26715 | 	Val Loss: 0.09564
#
# Epoch  747
# 	Train Loss: 0.26146 | 	Val Loss: 0.09640
#
# Epoch  748
# 	Train Loss: 0.26201 | 	Val Loss: 0.09532
#
# Epoch  749
# 	Train Loss: 0.25909 | 	Val Loss: 0.09681
#
# Epoch  750
# 	Train Loss: 0.25991 | 	Val Loss: 0.09541
#
# Epoch  751
# 	Train Loss: 0.25775 | 	Val Loss: 0.09634
#
# Epoch  752
# 	Train Loss: 0.25906 | 	Val Loss: 0.09552
#
# Epoch  753
# 	Train Loss: 0.25803 | 	Val Loss: 0.09691
#
# Epoch  754
# 	Train Loss: 0.26061 | 	Val Loss: 0.09490
#
# Epoch  755
# 	Train Loss: 0.25959 | 	Val Loss: 0.09756
#
# Epoch  756
# 	Train Loss: 0.26037 | 	Val Loss: 0.09492
#
# Epoch  757
# 	Train Loss: 0.25716 | 	Val Loss: 0.09679
#
# Epoch  758
# 	Train Loss: 0.25774 | 	Val Loss: 0.09526
#
# Epoch  759
# 	Train Loss: 0.25498 | 	Val Loss: 0.09709
#
# Epoch  760
# 	Train Loss: 0.25697 | 	Val Loss: 0.09488
#
# Epoch  761
# 	Train Loss: 0.25424 | 	Val Loss: 0.09754
#
# Epoch  762
# 	Train Loss: 0.25564 | 	Val Loss: 0.09516
#
# Epoch  763
# 	Train Loss: 0.25201 | 	Val Loss: 0.09656
#
# Epoch  764
# 	Train Loss: 0.25499 | 	Val Loss: 0.09592
#
# Epoch  765
# 	Train Loss: 0.25187 | 	Val Loss: 0.09658
#
# Epoch  766
# 	Train Loss: 0.25597 | 	Val Loss: 0.09531
#
# Epoch  767
# 	Train Loss: 0.25306 | 	Val Loss: 0.09724
#
# Epoch  768
# 	Train Loss: 0.25848 | 	Val Loss: 0.09555
#
# Epoch  769
# 	Train Loss: 0.25554 | 	Val Loss: 0.09634
#
# Epoch  770
# 	Train Loss: 0.26325 | 	Val Loss: 0.09658
#
# Epoch  771
# 	Train Loss: 0.25872 | 	Val Loss: 0.09619
#
# Epoch  772
# 	Train Loss: 0.26308 | 	Val Loss: 0.09549
#
# Epoch  773
# 	Train Loss: 0.25701 | 	Val Loss: 0.09695
#
# Epoch  774
# 	Train Loss: 0.26013 | 	Val Loss: 0.09581
#
# Epoch  775
# 	Train Loss: 0.25473 | 	Val Loss: 0.09581
#
# Epoch  776
# 	Train Loss: 0.25797 | 	Val Loss: 0.09714
#
# Epoch  777
# 	Train Loss: 0.25310 | 	Val Loss: 0.09574
#
# Epoch  778
# 	Train Loss: 0.25438 | 	Val Loss: 0.09559
#
# Epoch  779
# 	Train Loss: 0.25444 | 	Val Loss: 0.09779
#
# Epoch  780
# 	Train Loss: 0.25802 | 	Val Loss: 0.09511
#
# Epoch  781
# 	Train Loss: 0.25463 | 	Val Loss: 0.09675
#
# Epoch  782
# 	Train Loss: 0.25467 | 	Val Loss: 0.09586
#
# Epoch  783
# 	Train Loss: 0.25206 | 	Val Loss: 0.09661
#
# Epoch  784
# 	Train Loss: 0.25293 | 	Val Loss: 0.09500
#
# Epoch  785
# 	Train Loss: 0.25260 | 	Val Loss: 0.09868
#
# Epoch  786
# 	Train Loss: 0.25476 | 	Val Loss: 0.09433
#
# Epoch  787
# 	Train Loss: 0.24967 | 	Val Loss: 0.09804
#
# Epoch  788
# 	Train Loss: 0.24891 | 	Val Loss: 0.09509
#
# Epoch  789
# 	Train Loss: 0.24669 | 	Val Loss: 0.09665
#
# Epoch  790
# 	Train Loss: 0.24937 | 	Val Loss: 0.09595
#
# Epoch  791
# 	Train Loss: 0.24740 | 	Val Loss: 0.09664
#
# Epoch  792
# 	Train Loss: 0.24914 | 	Val Loss: 0.09539
#
# Epoch  793
# 	Train Loss: 0.24753 | 	Val Loss: 0.09688
#
# Epoch  794
# 	Train Loss: 0.24940 | 	Val Loss: 0.09579
#
# Epoch  795
# 	Train Loss: 0.24924 | 	Val Loss: 0.09605
#
# Epoch  796
# 	Train Loss: 0.25111 | 	Val Loss: 0.09700
#
# Epoch  797
# 	Train Loss: 0.25084 | 	Val Loss: 0.09512
#
# Epoch  798
# 	Train Loss: 0.25011 | 	Val Loss: 0.09770
#
# Epoch  799
# 	Train Loss: 0.24958 | 	Val Loss: 0.09444
#
# Epoch  800
# 	Train Loss: 0.24786 | 	Val Loss: 0.09832
#
# Epoch  801
# 	Train Loss: 0.25028 | 	Val Loss: 0.09388
#
# Epoch  802
# 	Train Loss: 0.24969 | 	Val Loss: 0.09923
#
# Epoch  803
# 	Train Loss: 0.25668 | 	Val Loss: 0.09341
#
# Epoch  804
# 	Train Loss: 0.25852 | 	Val Loss: 0.09994
#
# Epoch  805
# 	Train Loss: 0.26246 | 	Val Loss: 0.09338
#
# Epoch  806
# 	Train Loss: 0.25638 | 	Val Loss: 0.09926
#
# Epoch  807
# 	Train Loss: 0.25383 | 	Val Loss: 0.09458
#
# Epoch  808
# 	Train Loss: 0.24532 | 	Val Loss: 0.09647
#
# Epoch  809
# 	Train Loss: 0.25121 | 	Val Loss: 0.09743
#
# Epoch  810
# 	Train Loss: 0.25029 | 	Val Loss: 0.09483
#
# Epoch  811
# 	Train Loss: 0.25893 | 	Val Loss: 0.09989
#
# Epoch  812
# 	Train Loss: 0.25475 | 	Val Loss: 0.09438
#
# Epoch  813
# 	Train Loss: 0.26032 | 	Val Loss: 0.09973
#
# Epoch  814
# 	Train Loss: 0.25596 | 	Val Loss: 0.09478
#
# Epoch  815
# 	Train Loss: 0.25893 | 	Val Loss: 0.09820
#
# Epoch  816
# 	Train Loss: 0.25378 | 	Val Loss: 0.09570
#
# Epoch  817
# 	Train Loss: 0.25195 | 	Val Loss: 0.09640
#
# Epoch  818
# 	Train Loss: 0.24547 | 	Val Loss: 0.09672
#
# Epoch  819
# 	Train Loss: 0.24497 | 	Val Loss: 0.09492
#
# Epoch  820
# 	Train Loss: 0.24149 | 	Val Loss: 0.09795
#
# Epoch  821
# 	Train Loss: 0.24321 | 	Val Loss: 0.09408
#
# Epoch  822
# 	Train Loss: 0.24159 | 	Val Loss: 0.09903
#
# Epoch  823
# 	Train Loss: 0.24455 | 	Val Loss: 0.09387
#
# Epoch  824
# 	Train Loss: 0.24349 | 	Val Loss: 0.09972
#
# Epoch  825
# 	Train Loss: 0.24640 | 	Val Loss: 0.09397
#
# Epoch  826
# 	Train Loss: 0.24509 | 	Val Loss: 0.09972
#
# Epoch  827
# 	Train Loss: 0.24742 | 	Val Loss: 0.09433
#
# Epoch  828
# 	Train Loss: 0.24566 | 	Val Loss: 0.09911
#
# Epoch  829
# 	Train Loss: 0.24773 | 	Val Loss: 0.09484
#
# Epoch  830
# 	Train Loss: 0.24567 | 	Val Loss: 0.09830
#
# Epoch  831
# 	Train Loss: 0.24828 | 	Val Loss: 0.09522
#
# Epoch  832
# 	Train Loss: 0.24669 | 	Val Loss: 0.09774
#
# Epoch  833
# 	Train Loss: 0.25146 | 	Val Loss: 0.09524
#
# Epoch  834
# 	Train Loss: 0.25233 | 	Val Loss: 0.09752
#
# Epoch  835
# 	Train Loss: 0.26193 | 	Val Loss: 0.09478
#
# Epoch  836
# 	Train Loss: 0.26891 | 	Val Loss: 0.09713
#
# Epoch  837
# 	Train Loss: 0.28476 | 	Val Loss: 0.09400
#
# Epoch  838
# 	Train Loss: 0.29809 | 	Val Loss: 0.09559
#
# Epoch  839
# 	Train Loss: 0.31083 | 	Val Loss: 0.09525
#
# Epoch  840
# 	Train Loss: 0.30659 | 	Val Loss: 0.09461
#
# Epoch  841
# 	Train Loss: 0.29119 | 	Val Loss: 0.10017
#
# Epoch  842
# 	Train Loss: 0.27003 | 	Val Loss: 0.09455
#
# Epoch  843
# 	Train Loss: 0.25528 | 	Val Loss: 0.09782
#
# Epoch  844
# 	Train Loss: 0.24896 | 	Val Loss: 0.09432
#
# Epoch  845
# 	Train Loss: 0.24151 | 	Val Loss: 0.09555
#
# Epoch  846
# 	Train Loss: 0.23548 | 	Val Loss: 0.09523
#
# Epoch  847
# 	Train Loss: 0.23569 | 	Val Loss: 0.09493
#
# Epoch  848
# 	Train Loss: 0.23213 | 	Val Loss: 0.09579
#
# Epoch  849
# 	Train Loss: 0.23551 | 	Val Loss: 0.09490
#
# Epoch  850
# 	Train Loss: 0.23286 | 	Val Loss: 0.09590
#
# Epoch  851
# 	Train Loss: 0.23701 | 	Val Loss: 0.09503
#
# Epoch  852
# 	Train Loss: 0.23465 | 	Val Loss: 0.09601
#
# Epoch  853
# 	Train Loss: 0.23832 | 	Val Loss: 0.09511
#
# Epoch  854
# 	Train Loss: 0.23510 | 	Val Loss: 0.09609
#
# Epoch  855
# 	Train Loss: 0.23754 | 	Val Loss: 0.09525
#
# Epoch  856
# 	Train Loss: 0.23341 | 	Val Loss: 0.09609
#
# Epoch  857
# 	Train Loss: 0.23554 | 	Val Loss: 0.09539
#
# Epoch  858
# 	Train Loss: 0.23162 | 	Val Loss: 0.09611
#
# Epoch  859
# 	Train Loss: 0.23403 | 	Val Loss: 0.09546
#
# Epoch  860
# 	Train Loss: 0.23056 | 	Val Loss: 0.09619
#
# Epoch  861
# 	Train Loss: 0.23331 | 	Val Loss: 0.09550
#
# Epoch  862
# 	Train Loss: 0.23010 | 	Val Loss: 0.09628
#
# Epoch  863
# 	Train Loss: 0.23313 | 	Val Loss: 0.09551
#
# Epoch  864
# 	Train Loss: 0.23001 | 	Val Loss: 0.09637
#
# Epoch  865
# 	Train Loss: 0.23319 | 	Val Loss: 0.09552
#
# Epoch  866
# 	Train Loss: 0.22999 | 	Val Loss: 0.09645
#
# Epoch  867
# 	Train Loss: 0.23316 | 	Val Loss: 0.09554
#
# Epoch  868
# 	Train Loss: 0.22978 | 	Val Loss: 0.09653
#
# Epoch  869
# 	Train Loss: 0.23284 | 	Val Loss: 0.09557
#
# Epoch  870
# 	Train Loss: 0.22928 | 	Val Loss: 0.09659
#
# Epoch  871
# 	Train Loss: 0.23225 | 	Val Loss: 0.09560
#
# Epoch  872
# 	Train Loss: 0.22861 | 	Val Loss: 0.09664
#
# Epoch  873
# 	Train Loss: 0.23158 | 	Val Loss: 0.09563
#
# Epoch  874
# 	Train Loss: 0.22797 | 	Val Loss: 0.09670
#
# Epoch  875
# 	Train Loss: 0.23099 | 	Val Loss: 0.09565
#
# Epoch  876
# 	Train Loss: 0.22745 | 	Val Loss: 0.09677
#
# Epoch  877
# 	Train Loss: 0.23053 | 	Val Loss: 0.09566
#
# Epoch  878
# 	Train Loss: 0.22704 | 	Val Loss: 0.09685
#
# Epoch  879
# 	Train Loss: 0.23016 | 	Val Loss: 0.09565
#
# Epoch  880
# 	Train Loss: 0.22671 | 	Val Loss: 0.09693
#
# Epoch  881
# 	Train Loss: 0.22984 | 	Val Loss: 0.09564
#
# Epoch  882
# 	Train Loss: 0.22640 | 	Val Loss: 0.09701
#
# Epoch  883
# 	Train Loss: 0.22952 | 	Val Loss: 0.09563
#
# Epoch  884
# 	Train Loss: 0.22610 | 	Val Loss: 0.09710
#
# Epoch  885
# 	Train Loss: 0.22921 | 	Val Loss: 0.09561
#
# Epoch  886
# 	Train Loss: 0.22584 | 	Val Loss: 0.09719
#
# Epoch  887
# 	Train Loss: 0.22895 | 	Val Loss: 0.09558
#
# Epoch  888
# 	Train Loss: 0.22570 | 	Val Loss: 0.09727
#
# Epoch  889
# 	Train Loss: 0.22882 | 	Val Loss: 0.09555
#
# Epoch  890
# 	Train Loss: 0.22577 | 	Val Loss: 0.09735
#
# Epoch  891
# 	Train Loss: 0.22893 | 	Val Loss: 0.09551
#
# Epoch  892
# ...
# 	Train Loss: 0.06550 | 	Val Loss: 0.10317
#
# Epoch  1612
# 	Train Loss: 0.06622 | 	Val Loss: 0.10530
#
# Epoch  1613
# 	Train Loss: 0.06548 | 	Val Loss: 0.10303
#
# Epoch  1614
# 	Train Loss: 0.06684 | 	Val Loss: 0.10557
#
# Epoch  1615
# 	Train Loss: 0.06583 | 	Val Loss: 0.10284
#
# Epoch  1616
# 	Train Loss: 0.06785 | 	Val Loss: 0.10586
#
# Epoch  1617
# 	Train Loss: 0.06687 | 	Val Loss: 0.10264
#
# Epoch  1618
# 	Train Loss: 0.06955 | 	Val Loss: 0.10611
#
# Epoch  1619
# 	Train Loss: 0.06885 | 	Val Loss: 0.10251
#
# Epoch  1620
# 	Train Loss: 0.07200 | 	Val Loss: 0.10619
#
# Epoch  1621
# 	Train Loss: 0.07149 | 	Val Loss: 0.10256
#
# Epoch  1622
# 	Train Loss: 0.07450 | 	Val Loss: 0.10602
#
# Epoch  1623
# 	Train Loss: 0.07348 | 	Val Loss: 0.10284
#
# Epoch  1624
# 	Train Loss: 0.07540 | 	Val Loss: 0.10561
#
# Epoch  1625
# 	Train Loss: 0.07287 | 	Val Loss: 0.10333
#
# Epoch  1626
# 	Train Loss: 0.07359 | 	Val Loss: 0.10510
#
# Epoch  1627
# 	Train Loss: 0.06983 | 	Val Loss: 0.10389
#
# Epoch  1628
# 	Train Loss: 0.07100 | 	Val Loss: 0.10458
#
# Epoch  1629
# 	Train Loss: 0.06818 | 	Val Loss: 0.10446
#
# Epoch  1630
# 	Train Loss: 0.07186 | 	Val Loss: 0.10402
#
# Epoch  1631
# 	Train Loss: 0.07325 | 	Val Loss: 0.10499
#
# Epoch  1632
# 	Train Loss: 0.08020 | 	Val Loss: 0.10337
#
# Epoch  1633
# 	Train Loss: 0.08977 | 	Val Loss: 0.10544
#
# Epoch  1634
# 	Train Loss: 0.08805 | 	Val Loss: 0.10299
#
# Epoch  1635
# 	Train Loss: 0.10116 | 	Val Loss: 0.10526
#
# Epoch  1636
# 	Train Loss: 0.08068 | 	Val Loss: 0.10373
#
# Epoch  1637
# 	Train Loss: 0.08368 | 	Val Loss: 0.10359
#
# Epoch  1638
# 	Train Loss: 0.07812 | 	Val Loss: 0.10576
#
# Epoch  1639
# 	Train Loss: 0.08388 | 	Val Loss: 0.10223
#
# Epoch  1640
# 	Train Loss: 0.08156 | 	Val Loss: 0.10690
#
# Epoch  1641
# 	Train Loss: 0.09162 | 	Val Loss: 0.10175
#
# Epoch  1642
# 	Train Loss: 0.08740 | 	Val Loss: 0.10703
#
# Epoch  1643
# 	Train Loss: 0.10296 | 	Val Loss: 0.10193
#
# Epoch  1644
# 	Train Loss: 0.09032 | 	Val Loss: 0.10627
#
# Epoch  1645
# 	Train Loss: 0.09104 | 	Val Loss: 0.10282
#
# Epoch  1646
# 	Train Loss: 0.07753 | 	Val Loss: 0.10525
#
# Epoch  1647
# 	Train Loss: 0.07590 | 	Val Loss: 0.10375
#
# Epoch  1648
# 	Train Loss: 0.07027 | 	Val Loss: 0.10458
#
# Epoch  1649
# 	Train Loss: 0.07165 | 	Val Loss: 0.10457
#
# Epoch  1650
# 	Train Loss: 0.06911 | 	Val Loss: 0.10388
#
# Epoch  1651
# 	Train Loss: 0.07231 | 	Val Loss: 0.10489
#
# Epoch  1652
# 	Train Loss: 0.06972 | 	Val Loss: 0.10362
#
# Epoch  1653
# 	Train Loss: 0.07367 | 	Val Loss: 0.10478
#
# Epoch  1654
# 	Train Loss: 0.07058 | 	Val Loss: 0.10380
#
# Epoch  1655
# 	Train Loss: 0.07542 | 	Val Loss: 0.10437
#
# Epoch  1656
# 	Train Loss: 0.07268 | 	Val Loss: 0.10424
#
# Epoch  1657
# 	Train Loss: 0.07790 | 	Val Loss: 0.10380
#
# Epoch  1658
# 	Train Loss: 0.07554 | 	Val Loss: 0.10475
#
# Epoch  1659
# 	Train Loss: 0.07808 | 	Val Loss: 0.10327
#
# Epoch  1660
# 	Train Loss: 0.07489 | 	Val Loss: 0.10511
#
# Epoch  1661
# 	Train Loss: 0.07292 | 	Val Loss: 0.10296
#
# Epoch  1662
# 	Train Loss: 0.06838 | 	Val Loss: 0.10517
#
# Epoch  1663
# 	Train Loss: 0.06488 | 	Val Loss: 0.10298
#
# Epoch  1664
# 	Train Loss: 0.06130 | 	Val Loss: 0.10494
#
# Epoch  1665
# 	Train Loss: 0.06006 | 	Val Loss: 0.10325
#
# Epoch  1666
# 	Train Loss: 0.05903 | 	Val Loss: 0.10466
#
# Epoch  1667
# 	Train Loss: 0.05932 | 	Val Loss: 0.10355
#
# Epoch  1668
# 	Train Loss: 0.05993 | 	Val Loss: 0.10450
#
# Epoch  1669
# 	Train Loss: 0.05977 | 	Val Loss: 0.10380
#
# Epoch  1670
# 	Train Loss: 0.06074 | 	Val Loss: 0.10440
#
# Epoch  1671
# 	Train Loss: 0.05932 | 	Val Loss: 0.10399
#
# Epoch  1672
# 	Train Loss: 0.05990 | 	Val Loss: 0.10435
#
# Epoch  1673
# 	Train Loss: 0.05831 | 	Val Loss: 0.10412
#
# Epoch  1674
# 	Train Loss: 0.05870 | 	Val Loss: 0.10436
#
# Epoch  1675
# 	Train Loss: 0.05774 | 	Val Loss: 0.10418
#
# Epoch  1676
# 	Train Loss: 0.05818 | 	Val Loss: 0.10439
#
# Epoch  1677
# 	Train Loss: 0.05779 | 	Val Loss: 0.10419
#
# Epoch  1678
# 	Train Loss: 0.05825 | 	Val Loss: 0.10444
#
# Epoch  1679
# 	Train Loss: 0.05822 | 	Val Loss: 0.10417
#
# Epoch  1680
# 	Train Loss: 0.05862 | 	Val Loss: 0.10448
#
# Epoch  1681
# 	Train Loss: 0.05906 | 	Val Loss: 0.10414
#
# Epoch  1682
# 	Train Loss: 0.05939 | 	Val Loss: 0.10452
#
# Epoch  1683
# 	Train Loss: 0.06116 | 	Val Loss: 0.10414
#
# Epoch  1684
# 	Train Loss: 0.06142 | 	Val Loss: 0.10453
#
# Epoch  1685
# 	Train Loss: 0.06678 | 	Val Loss: 0.10424
#
# Epoch  1686
# 	Train Loss: 0.06670 | 	Val Loss: 0.10444
#
# Epoch  1687
# 	Train Loss: 0.08193 | 	Val Loss: 0.10459
#
# Epoch  1688
# 	Train Loss: 0.08317 | 	Val Loss: 0.10405
#
# Epoch  1689
# 	Train Loss: 0.13135 | 	Val Loss: 0.10556
#
# Epoch  1690
# 	Train Loss: 0.10898 | 	Val Loss: 0.10269
#
# Epoch  1691
# 	Train Loss: 0.13981 | 	Val Loss: 0.10602
#
# Epoch  1692
# 	Train Loss: 0.09530 | 	Val Loss: 0.10271
#
# Epoch  1693
# 	Train Loss: 0.08872 | 	Val Loss: 0.10472
#
# Epoch  1694
# 	Train Loss: 0.07281 | 	Val Loss: 0.10374
#
# Epoch  1695
# 	Train Loss: 0.06935 | 	Val Loss: 0.10426
#
# Epoch  1696
# 	Train Loss: 0.06361 | 	Val Loss: 0.10437
#
# Epoch  1697
# 	Train Loss: 0.06329 | 	Val Loss: 0.10448
#
# Epoch  1698
# 	Train Loss: 0.05954 | 	Val Loss: 0.10446
#
# Epoch  1699
# 	Train Loss: 0.06001 | 	Val Loss: 0.10446
#
# Epoch  1700
# 	Train Loss: 0.05840 | 	Val Loss: 0.10445
#
# Epoch  1701
# 	Train Loss: 0.05964 | 	Val Loss: 0.10444
#
# Epoch  1702
# 	Train Loss: 0.05928 | 	Val Loss: 0.10446
#
# Epoch  1703
# 	Train Loss: 0.06085 | 	Val Loss: 0.10445
#
# Epoch  1704
# 	Train Loss: 0.06086 | 	Val Loss: 0.10447
#
# Epoch  1705
# 	Train Loss: 0.06240 | 	Val Loss: 0.10451
#
# Epoch  1706
# 	Train Loss: 0.06215 | 	Val Loss: 0.10443
#
# Epoch  1707
# 	Train Loss: 0.06331 | 	Val Loss: 0.10462
#
# Epoch  1708
# 	Train Loss: 0.06288 | 	Val Loss: 0.10432
#
# Epoch  1709
# 	Train Loss: 0.06362 | 	Val Loss: 0.10478
#
# Epoch  1710
# 	Train Loss: 0.06332 | 	Val Loss: 0.10413
#
# Epoch  1711
# 	Train Loss: 0.06359 | 	Val Loss: 0.10498
#
# Epoch  1712
# 	Train Loss: 0.06346 | 	Val Loss: 0.10390
#
# Epoch  1713
# 	Train Loss: 0.06308 | 	Val Loss: 0.10516
#
# Epoch  1714
# 	Train Loss: 0.06311 | 	Val Loss: 0.10369
#
# Epoch  1715
# 	Train Loss: 0.06197 | 	Val Loss: 0.10529
#
# Epoch  1716
# 	Train Loss: 0.06233 | 	Val Loss: 0.10355
#
# Epoch  1717
# 	Train Loss: 0.06044 | 	Val Loss: 0.10535
#
# Epoch  1718
# 	Train Loss: 0.06135 | 	Val Loss: 0.10348
#
# Epoch  1719
# 	Train Loss: 0.05876 | 	Val Loss: 0.10535
#
# Epoch  1720
# 	Train Loss: 0.06016 | 	Val Loss: 0.10348
#
# Epoch  1721
# 	Train Loss: 0.05703 | 	Val Loss: 0.10531
#
# Epoch  1722
# 	Train Loss: 0.05848 | 	Val Loss: 0.10354
#
# Epoch  1723
# 	Train Loss: 0.05530 | 	Val Loss: 0.10522
#
# Epoch  1724
# 	Train Loss: 0.05642 | 	Val Loss: 0.10365
#
# Epoch  1725
# 	Train Loss: 0.05374 | 	Val Loss: 0.10509
#
# Epoch  1726
# 	Train Loss: 0.05451 | 	Val Loss: 0.10378
#
# Epoch  1727
# 	Train Loss: 0.05250 | 	Val Loss: 0.10495
#
# Epoch  1728
# 	Train Loss: 0.05307 | 	Val Loss: 0.10391
#
# Epoch  1729
# 	Train Loss: 0.05162 | 	Val Loss: 0.10482
#
# Epoch  1730
# 	Train Loss: 0.05216 | 	Val Loss: 0.10405
#
# Epoch  1731
# 	Train Loss: 0.05113 | 	Val Loss: 0.10474
#
# Epoch  1732
# 	Train Loss: 0.05184 | 	Val Loss: 0.10416
#
# Epoch  1733
# 	Train Loss: 0.05110 | 	Val Loss: 0.10470
#
# Epoch  1734
# 	Train Loss: 0.05226 | 	Val Loss: 0.10424
#
# Epoch  1735
# 	Train Loss: 0.05179 | 	Val Loss: 0.10470
#
# Epoch  1736
# 	Train Loss: 0.05387 | 	Val Loss: 0.10430
#
# Epoch  1737
# 	Train Loss: 0.05382 | 	Val Loss: 0.10472
#
# Epoch  1738
# 	Train Loss: 0.05752 | 	Val Loss: 0.10436
#
# Epoch  1739
# 	Train Loss: 0.05827 | 	Val Loss: 0.10469
#
# Epoch  1740
# 	Train Loss: 0.06457 | 	Val Loss: 0.10448
#
# Epoch  1741
# 	Train Loss: 0.06633 | 	Val Loss: 0.10457
#
# Epoch  1742
# 	Train Loss: 0.07712 | 	Val Loss: 0.10464
#
# Epoch  1743
# 	Train Loss: 0.07883 | 	Val Loss: 0.10430
#
# Epoch  1744
# 	Train Loss: 0.10190 | 	Val Loss: 0.10493
#
# Epoch  1745
# 	Train Loss: 0.09517 | 	Val Loss: 0.10380
#
# Epoch  1746
# 	Train Loss: 0.14149 | 	Val Loss: 0.10570
#
# Epoch  1747
# 	Train Loss: 0.08083 | 	Val Loss: 0.10329
#
# Epoch  1748
# 	Train Loss: 0.08084 | 	Val Loss: 0.10437
#
# Epoch  1749
# 	Train Loss: 0.06755 | 	Val Loss: 0.10457
#
# Epoch  1750
# 	Train Loss: 0.06768 | 	Val Loss: 0.10467
#
# Epoch  1751
# 	Train Loss: 0.06238 | 	Val Loss: 0.10382
#
# Epoch  1752
# 	Train Loss: 0.06255 | 	Val Loss: 0.10559
#
# Epoch  1753
# 	Train Loss: 0.06243 | 	Val Loss: 0.10339
#
# Epoch  1754
# 	Train Loss: 0.06517 | 	Val Loss: 0.10493
#
# Epoch  1755
# 	Train Loss: 0.06956 | 	Val Loss: 0.10404
#
# Epoch  1756
# 	Train Loss: 0.06630 | 	Val Loss: 0.10478
#
# Epoch  1757
# 	Train Loss: 0.06989 | 	Val Loss: 0.10435
#
# Epoch  1758
# 	Train Loss: 0.06322 | 	Val Loss: 0.10427
#
# Epoch  1759
# 	Train Loss: 0.06406 | 	Val Loss: 0.10474
#
# Epoch  1760
# 	Train Loss: 0.06055 | 	Val Loss: 0.10383
#
# Epoch  1761
# 	Train Loss: 0.06108 | 	Val Loss: 0.10492
#
# Epoch  1762
# 	Train Loss: 0.05726 | 	Val Loss: 0.10382
#
# Epoch  1763
# 	Train Loss: 0.05885 | 	Val Loss: 0.10485
#
# Epoch  1764
# 	Train Loss: 0.05401 | 	Val Loss: 0.10394
#
# Epoch  1765
# 	Train Loss: 0.05487 | 	Val Loss: 0.10463
#
# Epoch  1766
# 	Train Loss: 0.05119 | 	Val Loss: 0.10414
#
# Epoch  1767
# 	Train Loss: 0.05146 | 	Val Loss: 0.10438
#
# Epoch  1768
# 	Train Loss: 0.04955 | 	Val Loss: 0.10424
#
# Epoch  1769
# 	Train Loss: 0.04993 | 	Val Loss: 0.10427
#
# Epoch  1770
# 	Train Loss: 0.04912 | 	Val Loss: 0.10417
#
# Epoch  1771
# 	Train Loss: 0.04993 | 	Val Loss: 0.10434
#
# Epoch  1772
# 	Train Loss: 0.04994 | 	Val Loss: 0.10399
#
# Epoch  1773
# 	Train Loss: 0.05161 | 	Val Loss: 0.10453
#
# Epoch  1774
# 	Train Loss: 0.05258 | 	Val Loss: 0.10374
#
# Epoch  1775
# 	Train Loss: 0.05581 | 	Val Loss: 0.10473
#
# Epoch  1776
# 	Train Loss: 0.05775 | 	Val Loss: 0.10351
#
# Epoch  1777
# 	Train Loss: 0.06206 | 	Val Loss: 0.10474
#
# Epoch  1778
# 	Train Loss: 0.06447 | 	Val Loss: 0.10345
#
# Epoch  1779
# 	Train Loss: 0.06618 | 	Val Loss: 0.10461
#
# Epoch  1780
# 	Train Loss: 0.06766 | 	Val Loss: 0.10348
#
# Epoch  1781
# 	Train Loss: 0.06656 | 	Val Loss: 0.10447
#
# Epoch  1782
# 	Train Loss: 0.06663 | 	Val Loss: 0.10349
#
# Epoch  1783
# 	Train Loss: 0.06504 | 	Val Loss: 0.10446
#
# Epoch  1784
# 	Train Loss: 0.06509 | 	Val Loss: 0.10346
#
# Epoch  1785
# 	Train Loss: 0.06250 | 	Val Loss: 0.10450
#
# Epoch  1786
# 	Train Loss: 0.06276 | 	Val Loss: 0.10347
#
# Epoch  1787
# 	Train Loss: 0.05869 | 	Val Loss: 0.10455
#
# Epoch  1788
# 	Train Loss: 0.05894 | 	Val Loss: 0.10348
#
# Epoch  1789
# 	Train Loss: 0.05431 | 	Val Loss: 0.10462
#
# Epoch  1790
# 	Train Loss: 0.05474 | 	Val Loss: 0.10346
#
# Epoch  1791
# 	Train Loss: 0.05071 | 	Val Loss: 0.10470
#
# Epoch  1792
# 	Train Loss: 0.05156 | 	Val Loss: 0.10341
#
# Epoch  1793
# 	Train Loss: 0.04849 | 	Val Loss: 0.10477
#
# Epoch  1794
# 	Train Loss: 0.04992 | 	Val Loss: 0.10331
#
# Epoch  1795
# 	Train Loss: 0.04816 | 	Val Loss: 0.10482
#
# Epoch  1796
# 	Train Loss: 0.05125 | 	Val Loss: 0.10313
#
# Epoch  1797
# 	Train Loss: 0.05165 | 	Val Loss: 0.10483
#
# Epoch  1798
# 	Train Loss: 0.05799 | 	Val Loss: 0.10284
#
# Epoch  1799
# 	Train Loss: 0.05980 | 	Val Loss: 0.10488
#
# Epoch  1800
# 	Train Loss: 0.06514 | 	Val Loss: 0.10260
#
# Epoch  1801
# 	Train Loss: 0.06497 | 	Val Loss: 0.10486
#
# Epoch  1802
# 	Train Loss: 0.06717 | 	Val Loss: 0.10244
#
# Epoch  1803
# 	Train Loss: 0.06542 | 	Val Loss: 0.10469
#
# Epoch  1804
# 	Train Loss: 0.06600 | 	Val Loss: 0.10249
#
# Epoch  1805
# 	Train Loss: 0.06696 | 	Val Loss: 0.10433
#
# Epoch  1806
# 	Train Loss: 0.06528 | 	Val Loss: 0.10285
#
# Epoch  1807
# 	Train Loss: 0.06851 | 	Val Loss: 0.10390
#
# Epoch  1808
# 	Train Loss: 0.06293 | 	Val Loss: 0.10367
#
# Epoch  1809
# 	Train Loss: 0.06521 | 	Val Loss: 0.10351
#
# Epoch  1810
# 	Train Loss: 0.05572 | 	Val Loss: 0.10444
#
# Epoch  1811
# 	Train Loss: 0.05669 | 	Val Loss: 0.10335
#
# Epoch  1812
# 	Train Loss: 0.05499 | 	Val Loss: 0.10452
#
# Epoch  1813
# 	Train Loss: 0.06210 | 	Val Loss: 0.10333
#
# Epoch  1814
# 	Train Loss: 0.06287 | 	Val Loss: 0.10437
#
# Epoch  1815
# 	Train Loss: 0.07172 | 	Val Loss: 0.10340
#
# Epoch  1816
# 	Train Loss: 0.07061 | 	Val Loss: 0.10389
#
# Epoch  1817
# 	Train Loss: 0.07898 | 	Val Loss: 0.10332
#
# Epoch  1818
# 	Train Loss: 0.07441 | 	Val Loss: 0.10381
#
# Epoch  1819
# 	Train Loss: 0.08212 | 	Val Loss: 0.10285
#
# Epoch  1820
# 	Train Loss: 0.07651 | 	Val Loss: 0.10417
#
# Epoch  1821
# 	Train Loss: 0.07952 | 	Val Loss: 0.10236
#
# Epoch  1822
# 	Train Loss: 0.07092 | 	Val Loss: 0.10427
#
# Epoch  1823
# 	Train Loss: 0.06804 | 	Val Loss: 0.10241
#
# Epoch  1824
# 	Train Loss: 0.05966 | 	Val Loss: 0.10395
#
# Epoch  1825
# 	Train Loss: 0.05819 | 	Val Loss: 0.10287
#
# Epoch  1826
# 	Train Loss: 0.05341 | 	Val Loss: 0.10352
#
# Epoch  1827
# 	Train Loss: 0.05503 | 	Val Loss: 0.10351
#
# Epoch  1828
# 	Train Loss: 0.05212 | 	Val Loss: 0.10295
#
# Epoch  1829
# 	Train Loss: 0.05437 | 	Val Loss: 0.10408
#
# Epoch  1830
# 	Train Loss: 0.05158 | 	Val Loss: 0.10249
#
# Epoch  1831
# 	Train Loss: 0.05346 | 	Val Loss: 0.10409
#
# Epoch  1832
# 	Train Loss: 0.05074 | 	Val Loss: 0.10244
#
# Epoch  1833
# 	Train Loss: 0.05217 | 	Val Loss: 0.10400
#
# Epoch  1834
# 	Train Loss: 0.04963 | 	Val Loss: 0.10247
#
# Epoch  1835
# 	Train Loss: 0.05093 | 	Val Loss: 0.10403
#
# Epoch  1836
# 	Train Loss: 0.04868 | 	Val Loss: 0.10249
#
# Epoch  1837
# 	Train Loss: 0.05003 | 	Val Loss: 0.10409
#
# Epoch  1838
# 	Train Loss: 0.04810 | 	Val Loss: 0.10253
#
# Epoch  1839
# 	Train Loss: 0.04955 | 	Val Loss: 0.10408
#
# Epoch  1840
# 	Train Loss: 0.04794 | 	Val Loss: 0.10259
#
# Epoch  1841
# 	Train Loss: 0.04947 | 	Val Loss: 0.10403
#
# Epoch  1842
# 	Train Loss: 0.04813 | 	Val Loss: 0.10266
#
# Epoch  1843
# 	Train Loss: 0.04962 | 	Val Loss: 0.10395
#
# Epoch  1844
# 	Train Loss: 0.04849 | 	Val Loss: 0.10273
#
# Epoch  1845
# 	Train Loss: 0.04982 | 	Val Loss: 0.10387
#
# Epoch  1846
# 	Train Loss: 0.04891 | 	Val Loss: 0.10281
#
# Epoch  1847
# 	Train Loss: 0.05007 | 	Val Loss: 0.10377
#
# Epoch  1848
# 	Train Loss: 0.04960 | 	Val Loss: 0.10291
#
# Epoch  1849
# 	Train Loss: 0.05079 | 	Val Loss: 0.10367
#
# Epoch  1850
# 	Train Loss: 0.05121 | 	Val Loss: 0.10304
#
# Epoch  1851
# 	Train Loss: 0.05219 | 	Val Loss: 0.10358
#
# Epoch  1852
# 	Train Loss: 0.05360 | 	Val Loss: 0.10320
#
# Epoch  1853
# 	Train Loss: 0.05283 | 	Val Loss: 0.10353
#
# Epoch  1854
# 	Train Loss: 0.05405 | 	Val Loss: 0.10334
#
# Epoch  1855
# 	Train Loss: 0.05184 | 	Val Loss: 0.10347
#
# Epoch  1856
# 	Train Loss: 0.05249 | 	Val Loss: 0.10337
#
# Epoch  1857
# 	Train Loss: 0.05058 | 	Val Loss: 0.10348
#
# Epoch  1858
# 	Train Loss: 0.05144 | 	Val Loss: 0.10321
#
# Epoch  1859
# 	Train Loss: 0.04973 | 	Val Loss: 0.10366
#
# Epoch  1860
# 	Train Loss: 0.05092 | 	Val Loss: 0.10291
#
# Epoch  1861
# 	Train Loss: 0.04887 | 	Val Loss: 0.10389
#
# Epoch  1862
# 	Train Loss: 0.04987 | 	Val Loss: 0.10263
#
# Epoch  1863
# 	Train Loss: 0.04744 | 	Val Loss: 0.10401
#
# Epoch  1864
# 	Train Loss: 0.04809 | 	Val Loss: 0.10245
#
# Epoch  1865
# 	Train Loss: 0.04573 | 	Val Loss: 0.10401
#
# Epoch  1866
# 	Train Loss: 0.04648 | 	Val Loss: 0.10234
#
# Epoch  1867
# 	Train Loss: 0.04471 | 	Val Loss: 0.10394
#
# Epoch  1868
# 	Train Loss: 0.04665 | 	Val Loss: 0.10225
#
# Epoch  1869
# 	Train Loss: 0.04620 | 	Val Loss: 0.10388
#
# Epoch  1870
# 	Train Loss: 0.05080 | 	Val Loss: 0.10212
#
# Epoch  1871
# 	Train Loss: 0.05165 | 	Val Loss: 0.10390
#
# Epoch  1872
# 	Train Loss: 0.05669 | 	Val Loss: 0.10202
#
# Epoch  1873
# 	Train Loss: 0.05542 | 	Val Loss: 0.10393
#
# Epoch  1874
# 	Train Loss: 0.05649 | 	Val Loss: 0.10207
#
# Epoch  1875
# 	Train Loss: 0.04991 | 	Val Loss: 0.10377
#
# Epoch  1876
# 	Train Loss: 0.04784 | 	Val Loss: 0.10226
#
# Epoch  1877
# 	Train Loss: 0.04343 | 	Val Loss: 0.10348
#
# Epoch  1878
# 	Train Loss: 0.04249 | 	Val Loss: 0.10234
#
# Epoch  1879
# 	Train Loss: 0.04169 | 	Val Loss: 0.10338
#
# Epoch  1880
# 	Train Loss: 0.04205 | 	Val Loss: 0.10224
#
# Epoch  1881
# 	Train Loss: 0.04289 | 	Val Loss: 0.10345
#
# Epoch  1882
# 	Train Loss: 0.04364 | 	Val Loss: 0.10215
#
# Epoch  1883
# 	Train Loss: 0.04492 | 	Val Loss: 0.10353
#
# Epoch  1884
# 	Train Loss: 0.04581 | 	Val Loss: 0.10215
#
# Epoch  1885
# 	Train Loss: 0.04676 | 	Val Loss: 0.10363
#
# Epoch  1886
# 	Train Loss: 0.04766 | 	Val Loss: 0.10212
#
# Epoch  1887
# 	Train Loss: 0.04786 | 	Val Loss: 0.10378
#
# Epoch  1888
# 	Train Loss: 0.04863 | 	Val Loss: 0.10211
#
# Epoch  1889
# 	Train Loss: 0.04898 | 	Val Loss: 0.10379
#
# Epoch  1890
# 	Train Loss: 0.05022 | 	Val Loss: 0.10217
#
# Epoch  1891
# 	Train Loss: 0.05203 | 	Val Loss: 0.10353
#
# Epoch  1892
# 	Train Loss: 0.05413 | 	Val Loss: 0.10226
#
# Epoch  1893
# 	Train Loss: 0.05370 | 	Val Loss: 0.10327
#
# Epoch  1894
# 	Train Loss: 0.05435 | 	Val Loss: 0.10213
#
# Epoch  1895
# 	Train Loss: 0.05355 | 	Val Loss: 0.10327
#
# Epoch  1896
# 	Train Loss: 0.05463 | 	Val Loss: 0.10192
#
# Epoch  1897
# 	Train Loss: 0.06046 | 	Val Loss: 0.10353
#
# Epoch  1898
# 	Train Loss: 0.06330 | 	Val Loss: 0.10184
#
# Epoch  1899
# 	Train Loss: 0.08299 | 	Val Loss: 0.10382
#
# Epoch  1900
# 	Train Loss: 0.08840 | 	Val Loss: 0.10203
#
# Epoch  1901
# 	Train Loss: 0.18629 | 	Val Loss: 0.10654

# %% [markdown]
# <h2> Visualization of results</h2>

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %%
plot_loss(train_losses=train_losses, valid_losses=valid_losses)

# %% [markdown]
# <h2>Training with hyperparameters tuning</h2>
# <h3>This part is irrelevant and was aborted due to high power demand and slow computations on CPU.</h3>

# %%
def train_hyperparameters(config, data_dir=None):

    hyper_train_losses = []
    hyper_valid_losses = []
    
    hyper_model = TuningNeuralNetwork(5, config['Bias'], config['Batch_First'], config['NL'])

    mse = nn.MSELoss()
    optimizer = optim.Adam(hyper_model.parameters(), lr=config["lr"], momentum=config['mtm'])

    #load checkpoint data in case we want to continue stopped training process
    checkpoint = get_checkpoint()
    if checkpoint:
        with checkpoint.as_directory() as checkpoint_dir:
            data_path = Path(checkpoint_dir) / "data.pkl"
            with open(data_path, "rb") as fp:
                checkpoint_state = pickle.load(fp)
            start_epoch = checkpoint_state["epoch"]
            hyper_model.load_state_dict(checkpoint_state["net_state_dict"])
            optimizer.load_state_dict(checkpoint_state["optimizer_state_dict"])
    else:
        start_epoch = 0

    #change for different number of iterations
    n_epochs = 1300

    best_valid_loss = float('inf')

    for epoch in range(start_epoch, n_epochs + 1):

        train_loss = train(train_dataloader_5_days_trade_sign)
        valid_loss = evaluate(valid_dataloader_5_days_trade_sign)
        
        hyper_train_losses.append(train_loss)
        hyper_valid_losses.append(valid_loss)

        #save the best model
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            torch.save(model, 'saved_weights.pt')
        
        #early stop step
        if valid_loss > train_loss:
            break

        print("Epoch ",epoch_instance+1)
        print(f'\tTrain Loss: {train_loss:.5f} | ' + f'\tVal Loss: {valid_loss:.5f}\n')

        checkpoint_data = {
            "epoch": epoch,
            "net_state_dict": hyper_model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
        }
        with tempfile.TemporaryDirectory() as checkpoint_dir:
            data_path = Path(checkpoint_dir) / "data.pkl"
            with open(data_path, "wb") as fp:
                pickle.dump(checkpoint_data, fp)

            checkpoint = Checkpoint.from_directory(checkpoint_dir)
            train.report(
                checkpoint=checkpoint,
            )

    print("Finished Training")

# %%
config = {
    "LBias": tune.choice([True, False]),
    'Bias': tune.choice([True, False]),
    "DO": tune.choice([0.0, 0.1, 0.2, 0.3]),
    "NL": tune.choice([1, 2, 4, 8]),
    "lr": tune.loguniform(1e-5, 1e-1),
    'Batch_First': tune.choice([True, False]),
    'mtm': tune.choice([.0, .2, .4, .6, .8])
}

# %%
num_samples=20

scheduler = ASHAScheduler(
    metric="loss",
    mode="min",
    max_t=n_epochs,
    grace_period=1,
    reduction_factor=2,
)

result = tune.run(
    partial(train_hyperparameters, data_dir=None),
    resources_per_trial={
        "cpu": 4,
        #'gpu': 2  <--- change only if you have gpu for extremely fast calculations
        },
    config=config,
    num_samples=num_samples,
    scheduler=scheduler,
    checkpoint_at_end=True)

best_trial = result.get_best_trial("loss", 'min')

print(f"Best trial config: {best_trial.config}")

best_trained_model = NeuralNetwork(best_trial.config['Bias'], best_trial.config['Batch_First'], best_trial.config['NL'], best_trial.config['DO'], best_trial.config['LBias'])

best_checkpoint = result.get_best_checkpoint(trial=best_trial, mode="min")
with best_checkpoint.as_directory() as checkpoint_dir:
    data_path = Path(checkpoint_dir) / "data.pkl"
    with open(data_path, "rb") as fp:
        best_checkpoint_data = pickle.load(fp)

    best_trained_model.load_state_dict(best_checkpoint_data["net_state_dict"])
# Out:
# 2025-05-16 12:53:30,538	ERROR services.py:1362 -- Failed to start the dashboard , return code 3221226505
# 2025-05-16 12:53:30,542	ERROR services.py:1387 -- Error should be written to 'dashboard.log' or 'dashboard.err'. We are printing the last 20 lines for you. See 'https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#logging-directory-structure' to find where the log file is.
# 2025-05-16 12:53:30,548	ERROR services.py:1397 -- Couldn't read dashboard.log file. Error: 'utf-8' codec can't decode byte 0xb3 in position 31: invalid start byte. It means the dashboard is broken even before it initializes the logger (mostly dependency issues). Reading the dashboard.err file which contains stdout/stderr.
# 2025-05-16 12:53:30,552	ERROR services.py:1431 --
# The last 20 lines of C:\Users\X\AppData\Local\Temp\ray\session_2025-05-16_12-53-28_376526_23724\logs\dashboard.err (it contains the error message from the dashboard):
# 2025-05-16 12:53:30,744	INFO worker.py:1888 -- Started a local Ray instance.

# %% [markdown]
# <h2>Loading saved weights data and conducting Predictions</h2>
# <h3>Continued part after skipping the hyperparameter tuning</h3>

# %%
model=torch.load('saved_weights.pt', weights_only=False) #set weights_only to False to avoid bug

x_test_5_days_trade_sign= torch.tensor(x_test_5_days_trade_sign).float()

with torch.no_grad():
  y_test_pred_5_days_trade_sign = model(x_test_5_days_trade_sign)

y_test_pred_5_days_trade_sign = y_test_pred_5_days_trade_sign.numpy()[0]

# %%
idx=0
plt.plot(np.arange(y_train_5_days_trade_sign.shape[0], y_train_5_days_trade_sign.shape[0]+y_test_5_days_trade_sign.shape[0]),
         y_test_5_days_trade_sign[:,idx], color='black', label='test target')

plt.plot(np.arange(y_train_5_days_trade_sign.shape[0], y_train_5_days_trade_sign.shape[0]+y_test_pred_5_days_trade_sign.shape[0]),
         y_test_pred_5_days_trade_sign[:,idx], color='green', label='test prediction')

plt.title('future stock prices')
plt.xlabel('time [days]')
plt.ylabel('normalized price')
plt.legend(loc='best')

print(mean_absolute_error(y_test_5_days_trade_sign, y_test_pred_5_days_trade_sign))
print(mean_absolute_percentage_error(y_test_5_days_trade_sign, y_test_pred_5_days_trade_sign))
# Out:
# 0.16816132378263826
# 0.19900171250129145
